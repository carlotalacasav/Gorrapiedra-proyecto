# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
years = [2020, 2021, 2022, 2023, 2024]
data = pd.read_csv('data/formated data/data_{}.csv'.format(years[0]))
data = data[data['year'] == years[0]]

weather_data = pd.read_csv('data/weather_data/weather_data_{}.csv'.format(years[0]))

for year in years[1:]:
    curr_data = pd.read_csv('data/formated data/data_{}.csv'.format(year))
    curr_data['year'] = year
    curr_data = curr_data[curr_data['year'] == year]
    data = pd.concat([data,curr_data])
    weather_data = pd.concat([weather_data,pd.read_csv('data/weather_data/weather_data_{}.csv'.format(year))])

data = data[['station_id', 'year', 'month', 'day', 'hour', 'ctx-4', 'ctx-3', 'ctx-2', 'ctx-1', 'percentage_docks_available']]
data['date'] = data['year'].astype(int).astype(str)+'/'+data['month'].astype(int).astype(str)+'/' + data['day'].astype(int).astype(str)+'/'+data['hour'].astype(int).astype(str)
data.sort_values(['year', 'month','day','hour'], ascending = True)

weather_data = weather_data[['year','month','day','hour','mm_precip','temperature']]
weather_data['date'] = weather_data['year'].astype(int).astype(str)+'/'+weather_data['month'].astype(int).astype(str)+'/' + weather_data['day'].astype(int).astype(str)+'/'+weather_data['hour'].astype(int).astype(str)
weather_data = weather_data[['mm_precip', 'temperature', 'date']]

# %%
ids_data = np.unique(data['station_id'])

# %%
len(data)
# Out:
# 3474268

# %%
data
# Out:
#         station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0              1.0  2020    1.0   1.0   2.0  0.522727  0.503788  0.469697
# 1              1.0  2020    1.0   1.0   7.0  0.289773  0.373106  0.304924
# 2              1.0  2020    1.0   1.0  12.0  0.253788  0.268939  0.350379
# 3              1.0  2020    1.0   1.0  17.0  0.390152  0.346591  0.255814
# 4              1.0  2020    1.0   1.0  22.0  0.083333  0.218992  0.437984
# ...            ...   ...    ...   ...   ...       ...       ...       ...
# 171897       496.0  2024    3.0  31.0   1.0  0.828704  0.787037  0.777778
# 171898       496.0  2024    3.0  31.0   6.0  0.930556  0.944444  0.935185
# 171899       496.0  2024    3.0  31.0  11.0  0.912037  0.884259  0.518519
# 171900       496.0  2024    3.0  31.0  16.0  0.245370  0.319444  0.277778
# 171901       496.0  2024    3.0  31.0  21.0  0.513889  0.435185  0.490741
#
#            ctx-1  percentage_docks_available          date
# 0       0.403409                    0.354167    2020/1/1/2
# 1       0.238636                    0.240530    2020/1/1/7
# 2       0.344697                    0.393939   2020/1/1/12
# 3       0.220930                    0.186047   2020/1/1/17
# 4       0.515504                    0.470930   2020/1/1/22
# ...          ...                         ...           ...
# 171897  0.853535                         NaN   2024/3/31/1
# 171898  0.856481                         NaN   2024/3/31/6
# 171899  0.157407                         NaN  2024/3/31/11
# 171900  0.305556                         NaN  2024/3/31/16
# 171901  0.504630                         NaN  2024/3/31/21
#
# [3474268 rows x 11 columns]

# %%
stations_info = pd.read_csv('data/info bicing/Informacio_Estacions_Bicing.csv')
stations_info = stations_info[['station_id', 'lat','lon', 'altitude', 'post_code', 'capacity']]
stations_info['post_code'] = '0' + stations_info['post_code'].astype(str)
stations_info
# Out:
#      station_id        lat       lon  altitude post_code  capacity
# 0             1  41.397978  2.180107      16.0     08013        45
# 1             2  41.395488  2.177198      17.0     08013        29
# 2             3  41.394156  2.181331      11.0     08013        27
# 3             4  41.393317  2.181248       8.0     08013        21
# 4             5  41.391103  2.180176       7.0     08018        39
# ..          ...        ...       ...       ...       ...       ...
# 501         515  41.435207  2.194800      19.0     08030        24
# 502         516  41.435460  2.200157      15.0     08030        21
# 503         517  41.462095  2.178959      44.0     08033        20
# 504         518  41.424689  2.157049     112.0     08032        27
# 505         519  41.424655  2.166289     110.0     08032        24
#
# [506 rows x 6 columns]

# %%
ids_stations = np.unique(stations_info['station_id'])

# %%
no_coincide = [id for id in ids_data if id not in ids_stations]
no_coincide
# Out:
# [48.0, 59.0, 93.0, 188.0, 429.0, 487.0, 520.0, 529.0, 530.0, 532.0]

# %%
len(data[data['station_id'].isin(no_coincide)])
# Out:
# 27370

# %%
full_data = data.copy()
len(full_data)
# Out:
# 3474268

# %%
full_data = pd.merge(full_data, stations_info, left_on = 'station_id', right_on = 'station_id')
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available         date        lat       lon  altitude  \
# 0                    0.354167   2020/1/1/2  41.397978  2.180107      16.0
# 1                    0.240530   2020/1/1/7  41.397978  2.180107      16.0
# 2                    0.393939  2020/1/1/12  41.397978  2.180107      16.0
# 3                    0.186047  2020/1/1/17  41.397978  2.180107      16.0
# 4                    0.470930  2020/1/1/22  41.397978  2.180107      16.0
#
#   post_code  capacity
# 0     08013        45
# 1     08013        45
# 2     08013        45
# 3     08013        45
# 4     08013        45

# %%
len(full_data)
# Out:
# 3446898

# %%
### HASTA AQUÍ BIEN

# %%
full_data.sort_values(['station_id','year','month','day','hour']).head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available         date        lat       lon  altitude  \
# 0                    0.354167   2020/1/1/2  41.397978  2.180107      16.0
# 1                    0.240530   2020/1/1/7  41.397978  2.180107      16.0
# 2                    0.393939  2020/1/1/12  41.397978  2.180107      16.0
# 3                    0.186047  2020/1/1/17  41.397978  2.180107      16.0
# 4                    0.470930  2020/1/1/22  41.397978  2.180107      16.0
#
#   post_code  capacity
# 0     08013        45
# 1     08013        45
# 2     08013        45
# 3     08013        45
# 4     08013        45

# %%
len(full_data)
# Out:
# 3446898

# %%
full_data = pd.merge(full_data, weather_data, left_on = 'date', right_on = 'date', how = 'left')
full_data
# Out:
#          station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0               1.0  2020    1.0   1.0   2.0  0.522727  0.503788  0.469697
# 1               1.0  2020    1.0   1.0   7.0  0.289773  0.373106  0.304924
# 2               1.0  2020    1.0   1.0  12.0  0.253788  0.268939  0.350379
# 3               1.0  2020    1.0   1.0  17.0  0.390152  0.346591  0.255814
# 4               1.0  2020    1.0   1.0  22.0  0.083333  0.218992  0.437984
# ...             ...   ...    ...   ...   ...       ...       ...       ...
# 3446893       431.0  2023   12.0  31.0   0.0  0.700000  0.700000  0.700000
# 3446894       431.0  2023   12.0  31.0   5.0  0.750000  0.750000  0.750000
# 3446895       431.0  2023   12.0  31.0  10.0  0.750000  0.750000  0.750000
# 3446896       431.0  2023   12.0  31.0  15.0  0.727273  0.650000  0.650000
# 3446897       431.0  2023   12.0  31.0  20.0  0.700000  0.700000  0.700000
#
#             ctx-1  percentage_docks_available           date        lat  \
# 0        0.403409                    0.354167     2020/1/1/2  41.397978
# 1        0.238636                    0.240530     2020/1/1/7  41.397978
# 2        0.344697                    0.393939    2020/1/1/12  41.397978
# 3        0.220930                    0.186047    2020/1/1/17  41.397978
# 4        0.515504                    0.470930    2020/1/1/22  41.397978
# ...           ...                         ...            ...        ...
# 3446893  0.700000                    0.750000   2023/12/31/0  41.383467
# 3446894  0.750000                    0.750000   2023/12/31/5  41.383467
# 3446895  0.750000                    0.750000  2023/12/31/10  41.383467
# 3446896  0.679167                    0.700000  2023/12/31/15  41.383467
# 3446897  0.700000                    0.700000  2023/12/31/20  41.383467
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 0        2.180107      16.0     08013        45        0.0         5.75
# 1        2.180107      16.0     08013        45        0.0         4.25
# 2        2.180107      16.0     08013        45        0.0        12.45
# 3        2.180107      16.0     08013        45        0.0         9.35
# 4        2.180107      16.0     08013        45        0.0         6.80
# ...           ...       ...       ...       ...        ...          ...
# 3446893  2.122175      53.0     08028        20        0.0        10.25
# 3446894  2.122175      53.0     08028        20        0.0         9.50
# 3446895  2.122175      53.0     08028        20        0.0        13.95
# 3446896  2.122175      53.0     08028        20        0.0        15.65
# 3446897  2.122175      53.0     08028        20        0.0        10.85
#
# [3446898 rows x 18 columns]

# %%
full_data[full_data['temperature'].isnull()]
# Out:
#          station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 1203            1.0  2020   10.0  25.0   2.0  0.294466  0.288043  0.217391
# 1501            1.0  2020   12.0  31.0   4.0  0.052536  0.043478  0.047101
# 1502            1.0  2020   12.0  31.0   9.0  0.478261  0.516304  0.548913
# 1503            1.0  2020   12.0  31.0  14.0  0.492754  0.429348  0.467391
# 1504            1.0  2020   12.0  31.0  19.0  0.413620  0.329710  0.264493
# ...             ...   ...    ...   ...   ...       ...       ...       ...
# 3446850       431.0  2023   12.0  22.0   1.0  0.720833  0.800000  0.800000
# 3446851       431.0  2023   12.0  22.0   6.0  0.800000  0.800000  0.800000
# 3446852       431.0  2023   12.0  22.0  11.0  0.762500  0.750000  0.750000
# 3446853       431.0  2023   12.0  22.0  16.0  0.750000  0.770833  0.850000
# 3446854       431.0  2023   12.0  22.0  21.0  0.816667  0.827900  0.908333
#
#             ctx-1  percentage_docks_available           date        lat  \
# 1203     0.195652                    0.187747   2020/10/25/2  41.397978
# 1501     0.148551                    0.478261   2020/12/31/4  41.397978
# 1502     0.547101                    0.481884   2020/12/31/9  41.397978
# 1503     0.423730                    0.414773  2020/12/31/14  41.397978
# 1504     0.209486                    0.122074  2020/12/31/19  41.397978
# ...           ...                         ...            ...        ...
# 3446850  0.800000                    0.800000   2023/12/22/1  41.383467
# 3446851  0.800000                    0.800000   2023/12/22/6  41.383467
# 3446852  0.704545                    0.745833  2023/12/22/11  41.383467
# 3446853  0.850000                    0.850000  2023/12/22/16  41.383467
# 3446854  0.950000                    0.950000  2023/12/22/21  41.383467
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 1203     2.180107      16.0     08013        45        NaN          NaN
# 1501     2.180107      16.0     08013        45        NaN          NaN
# 1502     2.180107      16.0     08013        45        NaN          NaN
# 1503     2.180107      16.0     08013        45        NaN          NaN
# 1504     2.180107      16.0     08013        45        NaN          NaN
# ...           ...       ...       ...       ...        ...          ...
# 3446850  2.122175      53.0     08028        20        NaN          NaN
# 3446851  2.122175      53.0     08028        20        NaN          NaN
# 3446852  2.122175      53.0     08028        20        NaN          NaN
# 3446853  2.122175      53.0     08028        20        NaN          NaN
# 3446854  2.122175      53.0     08028        20        NaN          NaN
#
# [7022 rows x 18 columns]

# %%
full_data[full_data['mm_precip'].isnull()]
# Out:
#          station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 1203            1.0  2020   10.0  25.0   2.0  0.294466  0.288043  0.217391
# 1501            1.0  2020   12.0  31.0   4.0  0.052536  0.043478  0.047101
# 1502            1.0  2020   12.0  31.0   9.0  0.478261  0.516304  0.548913
# 1503            1.0  2020   12.0  31.0  14.0  0.492754  0.429348  0.467391
# 1504            1.0  2020   12.0  31.0  19.0  0.413620  0.329710  0.264493
# ...             ...   ...    ...   ...   ...       ...       ...       ...
# 3446850       431.0  2023   12.0  22.0   1.0  0.720833  0.800000  0.800000
# 3446851       431.0  2023   12.0  22.0   6.0  0.800000  0.800000  0.800000
# 3446852       431.0  2023   12.0  22.0  11.0  0.762500  0.750000  0.750000
# 3446853       431.0  2023   12.0  22.0  16.0  0.750000  0.770833  0.850000
# 3446854       431.0  2023   12.0  22.0  21.0  0.816667  0.827900  0.908333
#
#             ctx-1  percentage_docks_available           date        lat  \
# 1203     0.195652                    0.187747   2020/10/25/2  41.397978
# 1501     0.148551                    0.478261   2020/12/31/4  41.397978
# 1502     0.547101                    0.481884   2020/12/31/9  41.397978
# 1503     0.423730                    0.414773  2020/12/31/14  41.397978
# 1504     0.209486                    0.122074  2020/12/31/19  41.397978
# ...           ...                         ...            ...        ...
# 3446850  0.800000                    0.800000   2023/12/22/1  41.383467
# 3446851  0.800000                    0.800000   2023/12/22/6  41.383467
# 3446852  0.704545                    0.745833  2023/12/22/11  41.383467
# 3446853  0.850000                    0.850000  2023/12/22/16  41.383467
# 3446854  0.950000                    0.950000  2023/12/22/21  41.383467
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 1203     2.180107      16.0     08013        45        NaN          NaN
# 1501     2.180107      16.0     08013        45        NaN          NaN
# 1502     2.180107      16.0     08013        45        NaN          NaN
# 1503     2.180107      16.0     08013        45        NaN          NaN
# 1504     2.180107      16.0     08013        45        NaN          NaN
# ...           ...       ...       ...       ...        ...          ...
# 3446850  2.122175      53.0     08028        20        NaN          NaN
# 3446851  2.122175      53.0     08028        20        NaN          NaN
# 3446852  2.122175      53.0     08028        20        NaN          NaN
# 3446853  2.122175      53.0     08028        20        NaN          NaN
# 3446854  2.122175      53.0     08028        20        NaN          NaN
#
# [7022 rows x 18 columns]

# %%
full_data['temperature'] = full_data['temperature'].fillna(value = full_data['temperature'].mean())
full_data['mm_precip'] = full_data['mm_precip'].fillna(value = full_data['mm_precip'].mean())

# %%
len(full_data)
# Out:
# 3446898

# %%
## HASTA AQUÍ TODO BIEN

# %%
codigos_postales_bcn = np.unique(full_data['post_code'])

locations = pd.read_csv('data/locations_data/barna_pics.csv', encoding = 'utf-16').groupby('addresses_zip_code').size().reset_index()
locations.columns = ['post_code', 'rating']
locations['post_code'] = '0'+locations['post_code'].astype(int).astype(str)

locations.head()
# Out:
#   post_code  rating
# 0     08001      30
# 1     08002      40
# 2     08003      42
# 3     08004      24
# 4     08005      21

# %%
data_zip = np.unique(full_data['post_code'])
locations_zip = np.unique(locations['post_code'])

# %%
zip_not_coinc = [code for code in data_zip if code not in locations_zip]
zip_not_coinc
# Out:
# ['08040', '08930']

# %%
full_data[full_data['post_code'].isin(zip_not_coinc)]
# Out:
#         station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 63159         10.0  2020   10.0   8.0  13.0  0.550000  0.560000  1.000000
# 63160         10.0  2020   10.0   8.0  18.0  1.000000  0.650503  0.579268
# 63161         10.0  2020   10.0   8.0  23.0  0.560976  0.560976  0.560976
# 63162         10.0  2020   10.0   9.0   4.0  0.553571  0.571429  0.571429
# 63163         10.0  2020   10.0   9.0   9.0  0.571429  0.559524  0.547619
# ...            ...   ...    ...   ...   ...       ...       ...       ...
# 236318        35.0  2024    3.0  30.0  22.0  0.114198  0.152778  0.126543
# 236319        35.0  2024    3.0  31.0   3.0  0.152778  0.158951  0.148148
# 236320        35.0  2024    3.0  31.0   8.0  0.146605  0.129630  0.135802
# 236321        35.0  2024    3.0  31.0  13.0  0.149691  0.069444  0.035494
# 236322        35.0  2024    3.0  31.0  18.0  0.351852  0.351852  0.351852
#
#            ctx-1  percentage_docks_available          date        lat  \
# 63159   1.000000                    1.000000  2020/10/8/13  41.346775
# 63160   0.560976                    0.560976  2020/10/8/18  41.346775
# 63161   0.584525                    0.557124  2020/10/8/23  41.346775
# 63162   0.571429                    0.571429   2020/10/9/4  41.346775
# 63163   0.547619                    0.547619   2020/10/9/9  41.346775
# ...          ...                         ...           ...        ...
# 236318  0.125000                         NaN  2024/3/30/22  41.413483
# 236319  0.148148                         NaN   2024/3/31/3  41.413483
# 236320  0.165123                         NaN   2024/3/31/8  41.413483
# 236321  0.155864                         NaN  2024/3/31/13  41.413483
# 236322  0.351852                         NaN  2024/3/31/18  41.413483
#
#              lon  altitude post_code  capacity  mm_precip  temperature
# 63159   2.143623       4.0     08040        43       0.00        22.80
# 63160   2.143623       4.0     08040        43       0.00        18.95
# 63161   2.143623       4.0     08040        43       0.00        17.30
# 63162   2.143623       4.0     08040        43       0.00        16.40
# 63163   2.143623       4.0     08040        43       0.00        23.75
# ...          ...       ...       ...       ...        ...          ...
# 236318  2.220691       5.0     08930        54       0.40        13.25
# 236319  2.220691       5.0     08930        54       0.00        13.45
# 236320  2.220691       5.0     08930        54       0.00        15.50
# 236321  2.220691       5.0     08930        54       2.25        13.00
# 236322  2.220691       5.0     08930        54       0.65        12.70
#
# [12512 rows x 18 columns]

# %%
#full_data = pd.merge(full_data, poligs_bcn_locs, left_on = 'post_code', right_on = 'post_code')
full_data = pd.merge(full_data, locations, left_on = 'post_code', right_on = 'post_code', how = 'left')
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available         date        lat       lon  altitude  \
# 0                    0.354167   2020/1/1/2  41.397978  2.180107      16.0
# 1                    0.240530   2020/1/1/7  41.397978  2.180107      16.0
# 2                    0.393939  2020/1/1/12  41.397978  2.180107      16.0
# 3                    0.186047  2020/1/1/17  41.397978  2.180107      16.0
# 4                    0.470930  2020/1/1/22  41.397978  2.180107      16.0
#
#   post_code  capacity  mm_precip  temperature  rating
# 0     08013        45        0.0         5.75     6.0
# 1     08013        45        0.0         4.25     6.0
# 2     08013        45        0.0        12.45     6.0
# 3     08013        45        0.0         9.35     6.0
# 4     08013        45        0.0         6.80     6.0

# %%
len(full_data)
# Out:
# 3446898

# %%
full_data[full_data['rating'].isnull()]
# Out:
#         station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 63159         10.0  2020   10.0   8.0  13.0  0.550000  0.560000  1.000000
# 63160         10.0  2020   10.0   8.0  18.0  1.000000  0.650503  0.579268
# 63161         10.0  2020   10.0   8.0  23.0  0.560976  0.560976  0.560976
# 63162         10.0  2020   10.0   9.0   4.0  0.553571  0.571429  0.571429
# 63163         10.0  2020   10.0   9.0   9.0  0.571429  0.559524  0.547619
# ...            ...   ...    ...   ...   ...       ...       ...       ...
# 236318        35.0  2024    3.0  30.0  22.0  0.114198  0.152778  0.126543
# 236319        35.0  2024    3.0  31.0   3.0  0.152778  0.158951  0.148148
# 236320        35.0  2024    3.0  31.0   8.0  0.146605  0.129630  0.135802
# 236321        35.0  2024    3.0  31.0  13.0  0.149691  0.069444  0.035494
# 236322        35.0  2024    3.0  31.0  18.0  0.351852  0.351852  0.351852
#
#            ctx-1  percentage_docks_available          date        lat  \
# 63159   1.000000                    1.000000  2020/10/8/13  41.346775
# 63160   0.560976                    0.560976  2020/10/8/18  41.346775
# 63161   0.584525                    0.557124  2020/10/8/23  41.346775
# 63162   0.571429                    0.571429   2020/10/9/4  41.346775
# 63163   0.547619                    0.547619   2020/10/9/9  41.346775
# ...          ...                         ...           ...        ...
# 236318  0.125000                         NaN  2024/3/30/22  41.413483
# 236319  0.148148                         NaN   2024/3/31/3  41.413483
# 236320  0.165123                         NaN   2024/3/31/8  41.413483
# 236321  0.155864                         NaN  2024/3/31/13  41.413483
# 236322  0.351852                         NaN  2024/3/31/18  41.413483
#
#              lon  altitude post_code  capacity  mm_precip  temperature  rating
# 63159   2.143623       4.0     08040        43       0.00        22.80     NaN
# 63160   2.143623       4.0     08040        43       0.00        18.95     NaN
# 63161   2.143623       4.0     08040        43       0.00        17.30     NaN
# 63162   2.143623       4.0     08040        43       0.00        16.40     NaN
# 63163   2.143623       4.0     08040        43       0.00        23.75     NaN
# ...          ...       ...       ...       ...        ...          ...     ...
# 236318  2.220691       5.0     08930        54       0.40        13.25     NaN
# 236319  2.220691       5.0     08930        54       0.00        13.45     NaN
# 236320  2.220691       5.0     08930        54       0.00        15.50     NaN
# 236321  2.220691       5.0     08930        54       2.25        13.00     NaN
# 236322  2.220691       5.0     08930        54       0.65        12.70     NaN
#
# [12512 rows x 19 columns]

# %%
full_data['rating'] = full_data['rating'].fillna(value = full_data['rating'].median())
full_data[full_data['rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station_id, year, month, day, hour, ctx-4, ctx-3, ctx-2, ctx-1, percentage_docks_available, date, lat, lon, altitude, post_code, capacity, mm_precip, temperature, rating]
# Index: []

# %%
data_ocio = pd.read_csv('data/locations_data/bcn_ocio.csv', encoding = 'utf-16').groupby('addresses_zip_code').size().reset_index()
data_ocio.columns = ['post_code', 'ocio']
data_ocio['post_code'] = '0'+data_ocio['post_code'].astype(int).astype(str)
data_ocio.head()
# Out:
#   post_code  ocio
# 0       080     4
# 1     08000     6
# 2     08001   151
# 3     08002   119
# 4     08003   173

# %%
full_data = pd.merge(full_data, data_ocio, left_on = 'post_code', right_on = 'post_code', how = 'left')

# %%
len(full_data)
# Out:
# 3446898

# %%
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available         date        lat       lon  altitude  \
# 0                    0.354167   2020/1/1/2  41.397978  2.180107      16.0
# 1                    0.240530   2020/1/1/7  41.397978  2.180107      16.0
# 2                    0.393939  2020/1/1/12  41.397978  2.180107      16.0
# 3                    0.186047  2020/1/1/17  41.397978  2.180107      16.0
# 4                    0.470930  2020/1/1/22  41.397978  2.180107      16.0
#
#   post_code  capacity  mm_precip  temperature  rating  ocio
# 0     08013        45        0.0         5.75     6.0  88.0
# 1     08013        45        0.0         4.25     6.0  88.0
# 2     08013        45        0.0        12.45     6.0  88.0
# 3     08013        45        0.0         9.35     6.0  88.0
# 4     08013        45        0.0         6.80     6.0  88.0

# %%
full_data[full_data['ocio'].isnull()]
# Out:
#         station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 229305        35.0  2020    1.0   1.0   1.0  0.240909  0.884615  0.916667
# 229306        35.0  2020    1.0   1.0   6.0  0.769231  0.769231  0.682692
# 229307        35.0  2020    1.0   1.0  11.0  0.628205  0.618590  0.653846
# 229308        35.0  2020    1.0   1.0  16.0  0.772436  0.721154  0.709790
# 229309        35.0  2020    1.0   1.0  21.0  0.769231  0.717949  0.634615
# ...            ...   ...    ...   ...   ...       ...       ...       ...
# 236318        35.0  2024    3.0  30.0  22.0  0.114198  0.152778  0.126543
# 236319        35.0  2024    3.0  31.0   3.0  0.152778  0.158951  0.148148
# 236320        35.0  2024    3.0  31.0   8.0  0.146605  0.129630  0.135802
# 236321        35.0  2024    3.0  31.0  13.0  0.149691  0.069444  0.035494
# 236322        35.0  2024    3.0  31.0  18.0  0.351852  0.351852  0.351852
#
#            ctx-1  percentage_docks_available          date        lat  \
# 229305  0.923077                    0.839744    2020/1/1/1  41.413483
# 229306  0.653846                    0.653846    2020/1/1/6  41.413483
# 229307  0.707101                    0.743590   2020/1/1/11  41.413483
# 229308  0.730769                    0.750000   2020/1/1/16  41.413483
# 229309  0.605769                    0.599359   2020/1/1/21  41.413483
# ...          ...                         ...           ...        ...
# 236318  0.125000                         NaN  2024/3/30/22  41.413483
# 236319  0.148148                         NaN   2024/3/31/3  41.413483
# 236320  0.165123                         NaN   2024/3/31/8  41.413483
# 236321  0.155864                         NaN  2024/3/31/13  41.413483
# 236322  0.351852                         NaN  2024/3/31/18  41.413483
#
#              lon  altitude post_code  capacity  mm_precip  temperature  \
# 229305  2.220691       5.0     08930        54       0.00         6.00
# 229306  2.220691       5.0     08930        54       0.00         4.25
# 229307  2.220691       5.0     08930        54       0.00        11.90
# 229308  2.220691       5.0     08930        54       0.00        10.20
# 229309  2.220691       5.0     08930        54       0.00         7.40
# ...          ...       ...       ...       ...        ...          ...
# 236318  2.220691       5.0     08930        54       0.40        13.25
# 236319  2.220691       5.0     08930        54       0.00        13.45
# 236320  2.220691       5.0     08930        54       0.00        15.50
# 236321  2.220691       5.0     08930        54       2.25        13.00
# 236322  2.220691       5.0     08930        54       0.65        12.70
#
#         rating  ocio
# 229305    21.0   NaN
# 229306    21.0   NaN
# 229307    21.0   NaN
# 229308    21.0   NaN
# 229309    21.0   NaN
# ...        ...   ...
# 236318    21.0   NaN
# 236319    21.0   NaN
# 236320    21.0   NaN
# 236321    21.0   NaN
# 236322    21.0   NaN
#
# [7018 rows x 20 columns]

# %%
full_data['ocio'] = full_data['ocio'].fillna(value = full_data['ocio'].median())
full_data[full_data['ocio'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station_id, year, month, day, hour, ctx-4, ctx-3, ctx-2, ctx-1, percentage_docks_available, date, lat, lon, altitude, post_code, capacity, mm_precip, temperature, rating, ocio]
# Index: []

# %%
len(full_data)
# Out:
# 3446898

# %%
bicis = pd.read_csv('data/locations_data/equipament.csv', encoding = 'utf-16')
carril_bicis = bicis[bicis["name"].str.contains("Carril - Bici")].groupby(['addresses_zip_code']).size().reset_index()
carril_bicis['addresses_zip_code']='0'+carril_bicis['addresses_zip_code'].astype(int).astype(str)
carril_bicis.columns = ['post_code', 'carriles']
carril_bicis.head()
full_data = pd.merge(full_data, carril_bicis, left_on = 'post_code', right_on = 'post_code', how = 'left')
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available  ...        lat       lon  altitude  post_code  \
# 0                    0.354167  ...  41.397978  2.180107      16.0      08013
# 1                    0.240530  ...  41.397978  2.180107      16.0      08013
# 2                    0.393939  ...  41.397978  2.180107      16.0      08013
# 3                    0.186047  ...  41.397978  2.180107      16.0      08013
# 4                    0.470930  ...  41.397978  2.180107      16.0      08013
#
#   capacity  mm_precip  temperature  rating  ocio  carriles
# 0       45        0.0         5.75     6.0  88.0       6.0
# 1       45        0.0         4.25     6.0  88.0       6.0
# 2       45        0.0        12.45     6.0  88.0       6.0
# 3       45        0.0         9.35     6.0  88.0       6.0
# 4       45        0.0         6.80     6.0  88.0       6.0
#
# [5 rows x 21 columns]

# %%
full_data[full_data['carriles'].isna()]
# Out:
#          station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 63159          10.0  2020   10.0   8.0  13.0  0.550000  0.560000  1.000000
# 63160          10.0  2020   10.0   8.0  18.0  1.000000  0.650503  0.579268
# 63161          10.0  2020   10.0   8.0  23.0  0.560976  0.560976  0.560976
# 63162          10.0  2020   10.0   9.0   4.0  0.553571  0.571429  0.571429
# 63163          10.0  2020   10.0   9.0   9.0  0.571429  0.559524  0.547619
# ...             ...   ...    ...   ...   ...       ...       ...       ...
# 3381496       511.0  2023   12.0  31.0   0.0  0.717593  0.555556  0.592593
# 3381497       511.0  2023   12.0  31.0   5.0  0.796296  0.879630  0.777778
# 3381498       511.0  2023   12.0  31.0  10.0  0.666667  0.680556  0.652778
# 3381499       511.0  2023   12.0  31.0  15.0  0.666667  0.712963  0.699074
# 3381500       511.0  2023   12.0  31.0  20.0  0.662037  0.673002  0.908626
#
#             ctx-1  percentage_docks_available  ...        lat       lon  \
# 63159    1.000000                    1.000000  ...  41.346775  2.143623
# 63160    0.560976                    0.560976  ...  41.346775  2.143623
# 63161    0.584525                    0.557124  ...  41.346775  2.143623
# 63162    0.571429                    0.571429  ...  41.346775  2.143623
# 63163    0.547619                    0.547619  ...  41.346775  2.143623
# ...           ...                         ...  ...        ...       ...
# 3381496  0.810185                    0.694444  ...  41.400686  2.154332
# 3381497  0.777778                    0.731481  ...  41.400686  2.154332
# 3381498  0.546296                    0.551282  ...  41.400686  2.154332
# 3381499  0.587963                    0.884259  ...  41.400686  2.154332
# 3381500  0.857212                    0.925439  ...  41.400686  2.154332
#
#          altitude  post_code capacity  mm_precip  temperature  rating  ocio  \
# 63159         4.0      08040       43        0.0        22.80    21.0   3.0
# 63160         4.0      08040       43        0.0        18.95    21.0   3.0
# 63161         4.0      08040       43        0.0        17.30    21.0   3.0
# 63162         4.0      08040       43        0.0        16.40    21.0   3.0
# 63163         4.0      08040       43        0.0        23.75    21.0   3.0
# ...           ...        ...      ...        ...          ...     ...   ...
# 3381496      61.0      08012       20        0.0        10.25    68.0  82.0
# 3381497      61.0      08012       20        0.0         9.50    68.0  82.0
# 3381498      61.0      08012       20        0.0        13.95    68.0  82.0
# 3381499      61.0      08012       20        0.0        15.65    68.0  82.0
# 3381500      61.0      08012       20        0.0        10.85    68.0  82.0
#
#          carriles
# 63159         NaN
# 63160         NaN
# 63161         NaN
# 63162         NaN
# 63163         NaN
# ...           ...
# 3381496       NaN
# 3381497       NaN
# 3381498       NaN
# 3381499       NaN
# 3381500       NaN
#
# [656687 rows x 21 columns]

# %%
zip_carriles = np.unique(carril_bicis['post_code'])
not_carriles = [code for code in data_zip if code not in zip_carriles]
not_carriles
# Out:
# ['08004',
#  '08007',
#  '08012',
#  '08021',
#  '08022',
#  '08023',
#  '08024',
#  '08031',
#  '08035',
#  '08036',
#  '08038',
#  '08039',
#  '08040',
#  '08930']

# %%
full_data['carriles'] = full_data['carriles'].fillna(value = full_data['carriles'].median())
full_data[full_data['carriles'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station_id, year, month, day, hour, ctx-4, ctx-3, ctx-2, ctx-1, percentage_docks_available, date, lat, lon, altitude, post_code, capacity, mm_precip, temperature, rating, ocio, carriles]
# Index: []
#
# [0 rows x 21 columns]

# %%
len(full_data)
# Out:
# 3446898

# %%
full_data
# Out:
#          station_id  year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0               1.0  2020    1.0   1.0   2.0  0.522727  0.503788  0.469697
# 1               1.0  2020    1.0   1.0   7.0  0.289773  0.373106  0.304924
# 2               1.0  2020    1.0   1.0  12.0  0.253788  0.268939  0.350379
# 3               1.0  2020    1.0   1.0  17.0  0.390152  0.346591  0.255814
# 4               1.0  2020    1.0   1.0  22.0  0.083333  0.218992  0.437984
# ...             ...   ...    ...   ...   ...       ...       ...       ...
# 3446893       431.0  2023   12.0  31.0   0.0  0.700000  0.700000  0.700000
# 3446894       431.0  2023   12.0  31.0   5.0  0.750000  0.750000  0.750000
# 3446895       431.0  2023   12.0  31.0  10.0  0.750000  0.750000  0.750000
# 3446896       431.0  2023   12.0  31.0  15.0  0.727273  0.650000  0.650000
# 3446897       431.0  2023   12.0  31.0  20.0  0.700000  0.700000  0.700000
#
#             ctx-1  percentage_docks_available  ...        lat       lon  \
# 0        0.403409                    0.354167  ...  41.397978  2.180107
# 1        0.238636                    0.240530  ...  41.397978  2.180107
# 2        0.344697                    0.393939  ...  41.397978  2.180107
# 3        0.220930                    0.186047  ...  41.397978  2.180107
# 4        0.515504                    0.470930  ...  41.397978  2.180107
# ...           ...                         ...  ...        ...       ...
# 3446893  0.700000                    0.750000  ...  41.383467  2.122175
# 3446894  0.750000                    0.750000  ...  41.383467  2.122175
# 3446895  0.750000                    0.750000  ...  41.383467  2.122175
# 3446896  0.679167                    0.700000  ...  41.383467  2.122175
# 3446897  0.700000                    0.700000  ...  41.383467  2.122175
#
#          altitude  post_code capacity  mm_precip  temperature  rating  ocio  \
# 0            16.0      08013       45        0.0         5.75     6.0  88.0
# 1            16.0      08013       45        0.0         4.25     6.0  88.0
# 2            16.0      08013       45        0.0        12.45     6.0  88.0
# 3            16.0      08013       45        0.0         9.35     6.0  88.0
# 4            16.0      08013       45        0.0         6.80     6.0  88.0
# ...           ...        ...      ...        ...          ...     ...   ...
# 3446893      53.0      08028       20        0.0        10.25    38.0  98.0
# 3446894      53.0      08028       20        0.0         9.50    38.0  98.0
# 3446895      53.0      08028       20        0.0        13.95    38.0  98.0
# 3446896      53.0      08028       20        0.0        15.65    38.0  98.0
# 3446897      53.0      08028       20        0.0        10.85    38.0  98.0
#
#          carriles
# 0             6.0
# 1             6.0
# 2             6.0
# 3             6.0
# 4             6.0
# ...           ...
# 3446893       2.0
# 3446894       2.0
# 3446895       2.0
# 3446896       2.0
# 3446897       2.0
#
# [3446898 rows x 21 columns]

# %%
#data.to_csv('../full_dataframe.csv')
#for year in years:
#    full_data[full_data['year']==year].to_csv('data/full dataframe/dataframe_{}.csv'.format(year))

# %%
full_data.size
# Out:
# 72384858

# %%
# Corregim el float que hi havia a year
full_data['year'] = full_data['year'].astype(int)
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available  ...        lat       lon  altitude  post_code  \
# 0                    0.354167  ...  41.397978  2.180107      16.0      08013
# 1                    0.240530  ...  41.397978  2.180107      16.0      08013
# 2                    0.393939  ...  41.397978  2.180107      16.0      08013
# 3                    0.186047  ...  41.397978  2.180107      16.0      08013
# 4                    0.470930  ...  41.397978  2.180107      16.0      08013
#
#   capacity  mm_precip  temperature  rating  ocio  carriles
# 0       45        0.0         5.75     6.0  88.0       6.0
# 1       45        0.0         4.25     6.0  88.0       6.0
# 2       45        0.0        12.45     6.0  88.0       6.0
# 3       45        0.0         9.35     6.0  88.0       6.0
# 4       45        0.0         6.80     6.0  88.0       6.0
#
# [5 rows x 21 columns]

# %%
# Convertim la date y/m/d/h a timestamp
full_data['timestamp'] = pd.to_datetime(full_data['date'], format='%Y/%m/%d/%H')

# Inici
start_date = pd.Timestamp('2020-01-01 00:00:00')
full_data['time'] = (full_data['timestamp'] - start_date).dt.total_seconds() // 3600
full_data['time'] = full_data['time'].astype(int)

# Ara fem drop de date i timestamp
full_data.drop(columns=['timestamp', 'date'], inplace=True)
full_data['time'].head()
# Out:
# 0     2
# 1     7
# 2    12
# 3    17
# 4    22
# Name: time, dtype: int64

# %%
festius = pd.read_csv('festius/Festius_generals_de_Catalunya.csv')
festius
# Out:
#      Any        Data             Nom del festiu
# 0   2020  01/01/2020                  Cap d'Any
# 1   2020  06/01/2020                       Reis
# 2   2020  10/04/2020             Divendres Sant
# 3   2020  13/04/2020  Dilluns de Pasqua Florida
# 4   2020  01/05/2020          Festa del Treball
# ..   ...         ...                        ...
# 75  2025  01/11/2025                 Tots Sants
# 76  2025  06/12/2025      Dia de la Constitució
# 77  2025  08/12/2025              La Immaculada
# 78  2025  25/12/2025                      Nadal
# 79  2025  26/12/2025                Sant Esteve
#
# [80 rows x 3 columns]

# %%
festius['Data'] = pd.to_datetime(festius['Data'], format='%d/%m/%Y')

# Extraiem dia, mes i any per poder comparar amb full data
festius['year'] = festius['Data'].dt.year
festius['month'] = festius['Data'].dt.month
festius['day'] = festius['Data'].dt.day

# %%
full_data = full_data.merge(festius[['year', 'month', 'day']], on=['year', 'month', 'day'], how='left', indicator=True)
full_data['festius'] = (full_data['_merge'] == 'both').astype(int)
full_data.drop(columns=['_merge'], inplace=True)
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available  ...  altitude  post_code  capacity mm_precip  \
# 0                    0.354167  ...      16.0      08013        45       0.0
# 1                    0.240530  ...      16.0      08013        45       0.0
# 2                    0.393939  ...      16.0      08013        45       0.0
# 3                    0.186047  ...      16.0      08013        45       0.0
# 4                    0.470930  ...      16.0      08013        45       0.0
#
#    temperature  rating  ocio  carriles  time  festius
# 0         5.75     6.0  88.0       6.0     2        1
# 1         4.25     6.0  88.0       6.0     7        1
# 2        12.45     6.0  88.0       6.0    12        1
# 3         9.35     6.0  88.0       6.0    17        1
# 4         6.80     6.0  88.0       6.0    22        1
#
# [5 rows x 22 columns]

# %%
years = full_data['year'].unique()

# Guardem full_data filtrat per anys ja que són fitxers grans
for year in years:
    yearly_data = full_data[full_data['year'] == year]
    yearly_data.to_csv(f'../full_data_{year}.csv', index=False)
    print(f'Saved full_data_{year}.csv')
# Out:
# Saved full_data_2020.csv
# Saved full_data_2021.csv
# Saved full_data_2022.csv
# Saved full_data_2023.csv
# Saved full_data_2024.csv
