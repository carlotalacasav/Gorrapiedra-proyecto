# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
years = [2020, 2021, 2022, 2023]
data = pd.read_csv('data/formated data/data_{}.csv'.format(years[0]))
data = data[data['year'] == years[0]]
weather_data = pd.read_csv('data/weather_data/weather_data_{}.csv'.format(years[0]))
for year in years[1:]:
    curr_data = pd.read_csv('data/formated data/data_{}.csv'.format(year))
    curr_data = curr_data[curr_data['year'] == year]
    data = pd.concat([data,curr_data])
    weather_data = pd.concat([weather_data,pd.read_csv('data/weather_data/weather_data_{}.csv'.format(year))])
data = data[['station_id', 'year', 'month', 'day', 'hour', 'ctx-4', 'ctx-3', 'ctx-2', 'ctx-1', 'percentage_docks_available']]
data['date'] = data['year'].astype(int).astype(str)+'/'+data['month'].astype(int).astype(str)+'/' + data['day'].astype(int).astype(str)+'/'+data['hour'].astype(int).astype(str)
data.sort_values(['year', 'month','day','hour'], ascending = True)

weather_data = weather_data[['year','month','day','hour','mm_precip','temperature']]
weather_data['date'] = weather_data['year'].astype(int).astype(str)+'/'+weather_data['month'].astype(int).astype(str)+'/' + weather_data['day'].astype(int).astype(str)+'/'+weather_data['hour'].astype(int).astype(str)
weather_data = weather_data[['mm_precip', 'temperature', 'date']]

# %%
ids_data = np.unique(data['station_id'])

# %%
len(data)
# Out:
# 3301796

# %%
data
# Out:
#         station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0              1.0  2020.0    1.0   1.0   2.0  0.522727  0.503788  0.469697
# 1              1.0  2020.0    1.0   1.0   7.0  0.289773  0.373106  0.304924
# 2              1.0  2020.0    1.0   1.0  12.0  0.253788  0.268939  0.350379
# 3              1.0  2020.0    1.0   1.0  17.0  0.390152  0.346591  0.255814
# 4              1.0  2020.0    1.0   1.0  22.0  0.083333  0.218992  0.437984
# ...            ...     ...    ...   ...   ...       ...       ...       ...
# 821637       520.0  2023.0   10.0  18.0  20.0  0.326923  0.218182  0.494444
# 821638       520.0  2023.0   10.0  19.0   1.0  0.625000  0.625000  0.625000
# 821639       520.0  2023.0   10.0  19.0   6.0  0.739583  0.760417  0.841346
# 821640       520.0  2023.0   10.0  19.0  11.0  0.750000  0.791667  0.369444
# 821641       520.0  2023.0   10.0  26.0  11.0  0.625000  0.696911  0.246296
#
#            ctx-1  percentage_docks_available           date
# 0       0.403409                    0.354167     2020/1/1/2
# 1       0.238636                    0.240530     2020/1/1/7
# 2       0.344697                    0.393939    2020/1/1/12
# 3       0.220930                    0.186047    2020/1/1/17
# 4       0.515504                    0.470930    2020/1/1/22
# ...          ...                         ...            ...
# 821637  0.531250                    0.645833  2023/10/18/20
# 821638  0.625000                    0.625000   2023/10/19/1
# 821639  0.776786                    0.750000   2023/10/19/6
# 821640  0.754167                    0.638889  2023/10/19/11
# 821641  0.437847                    0.386111  2023/10/26/11
#
# [3301796 rows x 11 columns]

# %%
stations_info = pd.read_csv('data/info bicing/Informacio_Estacions_Bicing.csv')
stations_info = stations_info[['station_id', 'lat','lon', 'altitude', 'post_code', 'capacity']]
stations_info['post_code'] = '0' + stations_info['post_code'].astype(str)
stations_info
# Out:
#      station_id        lat       lon  altitude post_code  capacity
# 0             1  41.397978  2.180107      16.0     08013        45
# 1             2  41.395488  2.177198      17.0     08013        29
# 2             3  41.394156  2.181331      11.0     08013        27
# 3             4  41.393317  2.181248       8.0     08013        21
# 4             5  41.391103  2.180176       7.0     08018        39
# ..          ...        ...       ...       ...       ...       ...
# 501         515  41.435207  2.194800      19.0     08030        24
# 502         516  41.435460  2.200157      15.0     08030        21
# 503         517  41.462095  2.178959      44.0     08033        20
# 504         518  41.424689  2.157049     112.0     08032        27
# 505         519  41.424655  2.166289     110.0     08032        24
#
# [506 rows x 6 columns]

# %%
ids_stations = np.unique(stations_info['station_id'])

# %%
no_coincide = [id for id in ids_data if id not in ids_stations]
no_coincide
# Out:
# [48.0, 59.0, 93.0, 188.0, 429.0, 487.0, 520.0, 529.0, 530.0, 532.0]

# %%
len(data[data['station_id'].isin(no_coincide)])
# Out:
# 27362

# %%
full_data = data.copy()
len(full_data)
# Out:
# 3301796

# %%
full_data = pd.merge(full_data, stations_info, left_on = 'station_id', right_on = 'station_id')
full_data.head()
# Out:
#    station_id    year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0         1.0  2020.0    1.0  1.0   2.0  0.522727  0.503788  0.469697
# 1         1.0  2020.0    1.0  1.0   7.0  0.289773  0.373106  0.304924
# 2         1.0  2020.0    1.0  1.0  12.0  0.253788  0.268939  0.350379
# 3         1.0  2020.0    1.0  1.0  17.0  0.390152  0.346591  0.255814
# 4         1.0  2020.0    1.0  1.0  22.0  0.083333  0.218992  0.437984
#
#       ctx-1  percentage_docks_available         date        lat       lon  \
# 0  0.403409                    0.354167   2020/1/1/2  41.397978  2.180107
# 1  0.238636                    0.240530   2020/1/1/7  41.397978  2.180107
# 2  0.344697                    0.393939  2020/1/1/12  41.397978  2.180107
# 3  0.220930                    0.186047  2020/1/1/17  41.397978  2.180107
# 4  0.515504                    0.470930  2020/1/1/22  41.397978  2.180107
#
#    altitude post_code  capacity
# 0      16.0     08013        45
# 1      16.0     08013        45
# 2      16.0     08013        45
# 3      16.0     08013        45
# 4      16.0     08013        45

# %%
len(full_data)
# Out:
# 3274434

# %%
### HASTA AQUÍ BIEN

# %%
full_data.sort_values(['station_id','year','month','day','hour']).head()
# Out:
#    station_id    year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0         1.0  2020.0    1.0  1.0   2.0  0.522727  0.503788  0.469697
# 1         1.0  2020.0    1.0  1.0   7.0  0.289773  0.373106  0.304924
# 2         1.0  2020.0    1.0  1.0  12.0  0.253788  0.268939  0.350379
# 3         1.0  2020.0    1.0  1.0  17.0  0.390152  0.346591  0.255814
# 4         1.0  2020.0    1.0  1.0  22.0  0.083333  0.218992  0.437984
#
#       ctx-1  percentage_docks_available         date        lat       lon  \
# 0  0.403409                    0.354167   2020/1/1/2  41.397978  2.180107
# 1  0.238636                    0.240530   2020/1/1/7  41.397978  2.180107
# 2  0.344697                    0.393939  2020/1/1/12  41.397978  2.180107
# 3  0.220930                    0.186047  2020/1/1/17  41.397978  2.180107
# 4  0.515504                    0.470930  2020/1/1/22  41.397978  2.180107
#
#    altitude post_code  capacity
# 0      16.0     08013        45
# 1      16.0     08013        45
# 2      16.0     08013        45
# 3      16.0     08013        45
# 4      16.0     08013        45

# %%
len(full_data)
# Out:
# 3274434

# %%
full_data = pd.merge(full_data, weather_data, left_on = 'date', right_on = 'date', how = 'left')
full_data
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0               1.0  2020.0    1.0   1.0   2.0  0.522727  0.503788  0.469697
# 1               1.0  2020.0    1.0   1.0   7.0  0.289773  0.373106  0.304924
# 2               1.0  2020.0    1.0   1.0  12.0  0.253788  0.268939  0.350379
# 3               1.0  2020.0    1.0   1.0  17.0  0.390152  0.346591  0.255814
# 4               1.0  2020.0    1.0   1.0  22.0  0.083333  0.218992  0.437984
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 3274429       519.0  2023.0   12.0  31.0   1.0  0.913043  0.847826  0.713768
# 3274430       519.0  2023.0   12.0  31.0   6.0  0.648551  0.619565  0.608696
# 3274431       519.0  2023.0   12.0  31.0  11.0  0.826087  0.836957  0.898551
# 3274432       519.0  2023.0   12.0  31.0  16.0  1.000000  1.000000  0.931159
# 3274433       519.0  2023.0   12.0  31.0  21.0  0.887681  0.905797  0.800725
#
#             ctx-1  percentage_docks_available           date        lat  \
# 0        0.403409                    0.354167     2020/1/1/2  41.397978
# 1        0.238636                    0.240530     2020/1/1/7  41.397978
# 2        0.344697                    0.393939    2020/1/1/12  41.397978
# 3        0.220930                    0.186047    2020/1/1/17  41.397978
# 4        0.515504                    0.470930    2020/1/1/22  41.397978
# ...           ...                         ...            ...        ...
# 3274429  0.731884                    0.659420   2023/12/31/1  41.424655
# 3274430  0.608696                    0.735507   2023/12/31/6  41.424655
# 3274431  0.939799                    1.000000  2023/12/31/11  41.424655
# 3274432  0.923913                    0.869565  2023/12/31/16  41.424655
# 3274433  0.746377                    0.713768  2023/12/31/21  41.424655
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 0        2.180107      16.0     08013        45        0.0         5.75
# 1        2.180107      16.0     08013        45        0.0         4.25
# 2        2.180107      16.0     08013        45        0.0        12.45
# 3        2.180107      16.0     08013        45        0.0         9.35
# 4        2.180107      16.0     08013        45        0.0         6.80
# ...           ...       ...       ...       ...        ...          ...
# 3274429  2.166289     110.0     08032        24        0.0        11.10
# 3274430  2.166289     110.0     08032        24        0.0         8.95
# 3274431  2.166289     110.0     08032        24        0.0        17.35
# 3274432  2.166289     110.0     08032        24        0.0        13.85
# 3274433  2.166289     110.0     08032        24        0.0         9.80
#
# [3274434 rows x 18 columns]

# %%
full_data[full_data['temperature'].isnull()]
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 1203            1.0  2020.0   10.0  25.0   2.0  0.294466  0.288043  0.217391
# 1501            1.0  2020.0   12.0  31.0   4.0  0.052536  0.043478  0.047101
# 1502            1.0  2020.0   12.0  31.0   9.0  0.478261  0.516304  0.548913
# 1503            1.0  2020.0   12.0  31.0  14.0  0.492754  0.429348  0.467391
# 1504            1.0  2020.0   12.0  31.0  19.0  0.413620  0.329710  0.264493
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 3274386       519.0  2023.0   12.0  22.0   2.0  0.875000  0.850694  0.805556
# 3274387       519.0  2023.0   12.0  22.0   7.0  0.750000  0.722222  0.750000
# 3274388       519.0  2023.0   12.0  22.0  12.0  0.833333  0.802083  0.722222
# 3274389       519.0  2023.0   12.0  22.0  17.0  0.822917  0.871528  0.909722
# 3274390       519.0  2023.0   12.0  22.0  22.0  0.940972  0.940972  0.875000
#
#             ctx-1  percentage_docks_available           date        lat  \
# 1203     0.195652                    0.187747   2020/10/25/2  41.397978
# 1501     0.148551                    0.478261   2020/12/31/4  41.397978
# 1502     0.547101                    0.481884   2020/12/31/9  41.397978
# 1503     0.423730                    0.414773  2020/12/31/14  41.397978
# 1504     0.209486                    0.122074  2020/12/31/19  41.397978
# ...           ...                         ...            ...        ...
# 3274386  0.836806                    0.812500   2023/12/22/2  41.424655
# 3274387  0.799242                    0.805556   2023/12/22/7  41.424655
# 3274388  0.781250                    0.826389  2023/12/22/12  41.424655
# 3274389  0.939103                    0.977273  2023/12/22/17  41.424655
# 3274390  0.775641                    0.549242  2023/12/22/22  41.424655
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 1203     2.180107      16.0     08013        45        NaN          NaN
# 1501     2.180107      16.0     08013        45        NaN          NaN
# 1502     2.180107      16.0     08013        45        NaN          NaN
# 1503     2.180107      16.0     08013        45        NaN          NaN
# 1504     2.180107      16.0     08013        45        NaN          NaN
# ...           ...       ...       ...       ...        ...          ...
# 3274386  2.166289     110.0     08032        24        NaN          NaN
# 3274387  2.166289     110.0     08032        24        NaN          NaN
# 3274388  2.166289     110.0     08032        24        NaN          NaN
# 3274389  2.166289     110.0     08032        24        NaN          NaN
# 3274390  2.166289     110.0     08032        24        NaN          NaN
#
# [5117 rows x 18 columns]

# %%
full_data[full_data['mm_precip'].isnull()]
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 1203            1.0  2020.0   10.0  25.0   2.0  0.294466  0.288043  0.217391
# 1501            1.0  2020.0   12.0  31.0   4.0  0.052536  0.043478  0.047101
# 1502            1.0  2020.0   12.0  31.0   9.0  0.478261  0.516304  0.548913
# 1503            1.0  2020.0   12.0  31.0  14.0  0.492754  0.429348  0.467391
# 1504            1.0  2020.0   12.0  31.0  19.0  0.413620  0.329710  0.264493
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 3274386       519.0  2023.0   12.0  22.0   2.0  0.875000  0.850694  0.805556
# 3274387       519.0  2023.0   12.0  22.0   7.0  0.750000  0.722222  0.750000
# 3274388       519.0  2023.0   12.0  22.0  12.0  0.833333  0.802083  0.722222
# 3274389       519.0  2023.0   12.0  22.0  17.0  0.822917  0.871528  0.909722
# 3274390       519.0  2023.0   12.0  22.0  22.0  0.940972  0.940972  0.875000
#
#             ctx-1  percentage_docks_available           date        lat  \
# 1203     0.195652                    0.187747   2020/10/25/2  41.397978
# 1501     0.148551                    0.478261   2020/12/31/4  41.397978
# 1502     0.547101                    0.481884   2020/12/31/9  41.397978
# 1503     0.423730                    0.414773  2020/12/31/14  41.397978
# 1504     0.209486                    0.122074  2020/12/31/19  41.397978
# ...           ...                         ...            ...        ...
# 3274386  0.836806                    0.812500   2023/12/22/2  41.424655
# 3274387  0.799242                    0.805556   2023/12/22/7  41.424655
# 3274388  0.781250                    0.826389  2023/12/22/12  41.424655
# 3274389  0.939103                    0.977273  2023/12/22/17  41.424655
# 3274390  0.775641                    0.549242  2023/12/22/22  41.424655
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 1203     2.180107      16.0     08013        45        NaN          NaN
# 1501     2.180107      16.0     08013        45        NaN          NaN
# 1502     2.180107      16.0     08013        45        NaN          NaN
# 1503     2.180107      16.0     08013        45        NaN          NaN
# 1504     2.180107      16.0     08013        45        NaN          NaN
# ...           ...       ...       ...       ...        ...          ...
# 3274386  2.166289     110.0     08032        24        NaN          NaN
# 3274387  2.166289     110.0     08032        24        NaN          NaN
# 3274388  2.166289     110.0     08032        24        NaN          NaN
# 3274389  2.166289     110.0     08032        24        NaN          NaN
# 3274390  2.166289     110.0     08032        24        NaN          NaN
#
# [5117 rows x 18 columns]

# %%
full_data['temperature'] = full_data['temperature'].fillna(value = full_data['temperature'].mean())
full_data['mm_precip'] = full_data['mm_precip'].fillna(value = full_data['mm_precip'].mean())

# %%
len(full_data)
# Out:
# 3274434

# %%
## HASTA AQUÍ TODO BIEN

# %%
codigos_postales_bcn = np.unique(full_data['post_code'])

locations = pd.read_csv('data/locations_data/barna_pics.csv', encoding = 'utf-16').groupby('addresses_zip_code').size().reset_index()
locations.columns = ['post_code', 'rating']
locations['post_code'] = '0'+locations['post_code'].astype(int).astype(str)

locations.head()
# Out:
#   post_code  rating
# 0     08001      30
# 1     08002      40
# 2     08003      42
# 3     08004      24
# 4     08005      21

# %%
data_zip = np.unique(full_data['post_code'])
locations_zip = np.unique(locations['post_code'])

# %%
zip_not_coinc = [code for code in data_zip if code not in locations_zip]
zip_not_coinc
# Out:
# ['08040', '08930']

# %%
full_data[full_data['post_code'].isin(zip_not_coinc)]
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 13596          10.0  2020.0   10.0   8.0  13.0  0.550000  0.560000  1.000000
# 13597          10.0  2020.0   10.0   8.0  18.0  1.000000  0.650503  0.579268
# 13598          10.0  2020.0   10.0   8.0  23.0  0.560976  0.560976  0.560976
# 13599          10.0  2020.0   10.0   9.0   4.0  0.553571  0.571429  0.571429
# 13600          10.0  2020.0   10.0   9.0   9.0  0.571429  0.559524  0.547619
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 2514563        35.0  2023.0   12.0  31.0   1.0  0.433962  0.451258  0.452830
# 2514564        35.0  2023.0   12.0  31.0   6.0  0.396226  0.383164  0.377358
# 2514565        35.0  2023.0   12.0  31.0  11.0  0.388365  0.408805  0.400943
# 2514566        35.0  2023.0   12.0  31.0  16.0  0.441824  0.476415  0.496099
# 2514567        35.0  2023.0   12.0  31.0  21.0  0.493711  0.378931  0.415094
#
#             ctx-1  percentage_docks_available           date        lat  \
# 13596    1.000000                    1.000000   2020/10/8/13  41.346775
# 13597    0.560976                    0.560976   2020/10/8/18  41.346775
# 13598    0.584525                    0.557124   2020/10/8/23  41.346775
# 13599    0.571429                    0.571429    2020/10/9/4  41.346775
# 13600    0.547619                    0.547619    2020/10/9/9  41.346775
# ...           ...                         ...            ...        ...
# 2514563  0.452830                    0.413522   2023/12/31/1  41.413483
# 2514564  0.377358                    0.377358   2023/12/31/6  41.413483
# 2514565  0.402516                    0.422956  2023/12/31/11  41.413483
# 2514566  0.539308                    0.558176  2023/12/31/16  41.413483
# 2514567  0.415094                    0.439375  2023/12/31/21  41.413483
#
#               lon  altitude post_code  capacity  mm_precip  temperature
# 13596    2.143623       4.0     08040        43        0.0        22.80
# 13597    2.143623       4.0     08040        43        0.0        18.95
# 13598    2.143623       4.0     08040        43        0.0        17.30
# 13599    2.143623       4.0     08040        43        0.0        16.40
# 13600    2.143623       4.0     08040        43        0.0        23.75
# ...           ...       ...       ...       ...        ...          ...
# 2514563  2.220691       5.0     08930        54        0.0        11.10
# 2514564  2.220691       5.0     08930        54        0.0         8.95
# 2514565  2.220691       5.0     08930        54        0.0        17.35
# 2514566  2.220691       5.0     08930        54        0.0        13.85
# 2514567  2.220691       5.0     08930        54        0.0         9.80
#
# [12080 rows x 18 columns]

# %%
#full_data = pd.merge(full_data, poligs_bcn_locs, left_on = 'post_code', right_on = 'post_code')
full_data = pd.merge(full_data, locations, left_on = 'post_code', right_on = 'post_code', how = 'left')
full_data.head()
# Out:
#    station_id    year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0         1.0  2020.0    1.0  1.0   2.0  0.522727  0.503788  0.469697
# 1         1.0  2020.0    1.0  1.0   7.0  0.289773  0.373106  0.304924
# 2         1.0  2020.0    1.0  1.0  12.0  0.253788  0.268939  0.350379
# 3         1.0  2020.0    1.0  1.0  17.0  0.390152  0.346591  0.255814
# 4         1.0  2020.0    1.0  1.0  22.0  0.083333  0.218992  0.437984
#
#       ctx-1  percentage_docks_available         date        lat       lon  \
# 0  0.403409                    0.354167   2020/1/1/2  41.397978  2.180107
# 1  0.238636                    0.240530   2020/1/1/7  41.397978  2.180107
# 2  0.344697                    0.393939  2020/1/1/12  41.397978  2.180107
# 3  0.220930                    0.186047  2020/1/1/17  41.397978  2.180107
# 4  0.515504                    0.470930  2020/1/1/22  41.397978  2.180107
#
#    altitude post_code  capacity  mm_precip  temperature  rating
# 0      16.0     08013        45        0.0         5.75     6.0
# 1      16.0     08013        45        0.0         4.25     6.0
# 2      16.0     08013        45        0.0        12.45     6.0
# 3      16.0     08013        45        0.0         9.35     6.0
# 4      16.0     08013        45        0.0         6.80     6.0

# %%
len(full_data)
# Out:
# 3274434

# %%
full_data[full_data['rating'].isnull()]
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 13596          10.0  2020.0   10.0   8.0  13.0  0.550000  0.560000  1.000000
# 13597          10.0  2020.0   10.0   8.0  18.0  1.000000  0.650503  0.579268
# 13598          10.0  2020.0   10.0   8.0  23.0  0.560976  0.560976  0.560976
# 13599          10.0  2020.0   10.0   9.0   4.0  0.553571  0.571429  0.571429
# 13600          10.0  2020.0   10.0   9.0   9.0  0.571429  0.559524  0.547619
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 2514563        35.0  2023.0   12.0  31.0   1.0  0.433962  0.451258  0.452830
# 2514564        35.0  2023.0   12.0  31.0   6.0  0.396226  0.383164  0.377358
# 2514565        35.0  2023.0   12.0  31.0  11.0  0.388365  0.408805  0.400943
# 2514566        35.0  2023.0   12.0  31.0  16.0  0.441824  0.476415  0.496099
# 2514567        35.0  2023.0   12.0  31.0  21.0  0.493711  0.378931  0.415094
#
#             ctx-1  percentage_docks_available           date        lat  \
# 13596    1.000000                    1.000000   2020/10/8/13  41.346775
# 13597    0.560976                    0.560976   2020/10/8/18  41.346775
# 13598    0.584525                    0.557124   2020/10/8/23  41.346775
# 13599    0.571429                    0.571429    2020/10/9/4  41.346775
# 13600    0.547619                    0.547619    2020/10/9/9  41.346775
# ...           ...                         ...            ...        ...
# 2514563  0.452830                    0.413522   2023/12/31/1  41.413483
# 2514564  0.377358                    0.377358   2023/12/31/6  41.413483
# 2514565  0.402516                    0.422956  2023/12/31/11  41.413483
# 2514566  0.539308                    0.558176  2023/12/31/16  41.413483
# 2514567  0.415094                    0.439375  2023/12/31/21  41.413483
#
#               lon  altitude post_code  capacity  mm_precip  temperature  \
# 13596    2.143623       4.0     08040        43        0.0        22.80
# 13597    2.143623       4.0     08040        43        0.0        18.95
# 13598    2.143623       4.0     08040        43        0.0        17.30
# 13599    2.143623       4.0     08040        43        0.0        16.40
# 13600    2.143623       4.0     08040        43        0.0        23.75
# ...           ...       ...       ...       ...        ...          ...
# 2514563  2.220691       5.0     08930        54        0.0        11.10
# 2514564  2.220691       5.0     08930        54        0.0         8.95
# 2514565  2.220691       5.0     08930        54        0.0        17.35
# 2514566  2.220691       5.0     08930        54        0.0        13.85
# 2514567  2.220691       5.0     08930        54        0.0         9.80
#
#          rating
# 13596       NaN
# 13597       NaN
# 13598       NaN
# 13599       NaN
# 13600       NaN
# ...         ...
# 2514563     NaN
# 2514564     NaN
# 2514565     NaN
# 2514566     NaN
# 2514567     NaN
#
# [12080 rows x 19 columns]

# %%
full_data['rating'] = full_data['rating'].fillna(value = full_data['rating'].median())
full_data[full_data['rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station_id, year, month, day, hour, ctx-4, ctx-3, ctx-2, ctx-1, percentage_docks_available, date, lat, lon, altitude, post_code, capacity, mm_precip, temperature, rating]
# Index: []

# %%
data_ocio = pd.read_csv('data/locations_data/bcn_ocio.csv', encoding = 'utf-16').groupby('addresses_zip_code').size().reset_index()
data_ocio.columns = ['post_code', 'ocio']
data_ocio['post_code'] = '0'+data_ocio['post_code'].astype(int).astype(str)
data_ocio.head()
# Out:
#   post_code  ocio
# 0       080     4
# 1     08000     6
# 2     08001   151
# 3     08002   119
# 4     08003   173

# %%
full_data = pd.merge(full_data, data_ocio, left_on = 'post_code', right_on = 'post_code', how = 'left')

# %%
len(full_data)
# Out:
# 3274434

# %%
full_data.head()
# Out:
#    station_id    year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0         1.0  2020.0    1.0  1.0   2.0  0.522727  0.503788  0.469697
# 1         1.0  2020.0    1.0  1.0   7.0  0.289773  0.373106  0.304924
# 2         1.0  2020.0    1.0  1.0  12.0  0.253788  0.268939  0.350379
# 3         1.0  2020.0    1.0  1.0  17.0  0.390152  0.346591  0.255814
# 4         1.0  2020.0    1.0  1.0  22.0  0.083333  0.218992  0.437984
#
#       ctx-1  percentage_docks_available         date        lat       lon  \
# 0  0.403409                    0.354167   2020/1/1/2  41.397978  2.180107
# 1  0.238636                    0.240530   2020/1/1/7  41.397978  2.180107
# 2  0.344697                    0.393939  2020/1/1/12  41.397978  2.180107
# 3  0.220930                    0.186047  2020/1/1/17  41.397978  2.180107
# 4  0.515504                    0.470930  2020/1/1/22  41.397978  2.180107
#
#    altitude post_code  capacity  mm_precip  temperature  rating  ocio
# 0      16.0     08013        45        0.0         5.75     6.0  88.0
# 1      16.0     08013        45        0.0         4.25     6.0  88.0
# 2      16.0     08013        45        0.0        12.45     6.0  88.0
# 3      16.0     08013        45        0.0         9.35     6.0  88.0
# 4      16.0     08013        45        0.0         6.80     6.0  88.0

# %%
full_data[full_data['ocio'].isnull()]
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 47885          35.0  2020.0    1.0   1.0   1.0  0.240909  0.884615  0.916667
# 47886          35.0  2020.0    1.0   1.0   6.0  0.769231  0.769231  0.682692
# 47887          35.0  2020.0    1.0   1.0  11.0  0.628205  0.618590  0.653846
# 47888          35.0  2020.0    1.0   1.0  16.0  0.772436  0.721154  0.709790
# 47889          35.0  2020.0    1.0   1.0  21.0  0.769231  0.717949  0.634615
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 2514563        35.0  2023.0   12.0  31.0   1.0  0.433962  0.451258  0.452830
# 2514564        35.0  2023.0   12.0  31.0   6.0  0.396226  0.383164  0.377358
# 2514565        35.0  2023.0   12.0  31.0  11.0  0.388365  0.408805  0.400943
# 2514566        35.0  2023.0   12.0  31.0  16.0  0.441824  0.476415  0.496099
# 2514567        35.0  2023.0   12.0  31.0  21.0  0.493711  0.378931  0.415094
#
#             ctx-1  percentage_docks_available           date        lat  \
# 47885    0.923077                    0.839744     2020/1/1/1  41.413483
# 47886    0.653846                    0.653846     2020/1/1/6  41.413483
# 47887    0.707101                    0.743590    2020/1/1/11  41.413483
# 47888    0.730769                    0.750000    2020/1/1/16  41.413483
# 47889    0.605769                    0.599359    2020/1/1/21  41.413483
# ...           ...                         ...            ...        ...
# 2514563  0.452830                    0.413522   2023/12/31/1  41.413483
# 2514564  0.377358                    0.377358   2023/12/31/6  41.413483
# 2514565  0.402516                    0.422956  2023/12/31/11  41.413483
# 2514566  0.539308                    0.558176  2023/12/31/16  41.413483
# 2514567  0.415094                    0.439375  2023/12/31/21  41.413483
#
#               lon  altitude post_code  capacity  mm_precip  temperature  \
# 47885    2.220691       5.0     08930        54        0.0         6.00
# 47886    2.220691       5.0     08930        54        0.0         4.25
# 47887    2.220691       5.0     08930        54        0.0        11.90
# 47888    2.220691       5.0     08930        54        0.0        10.20
# 47889    2.220691       5.0     08930        54        0.0         7.40
# ...           ...       ...       ...       ...        ...          ...
# 2514563  2.220691       5.0     08930        54        0.0        11.10
# 2514564  2.220691       5.0     08930        54        0.0         8.95
# 2514565  2.220691       5.0     08930        54        0.0        17.35
# 2514566  2.220691       5.0     08930        54        0.0        13.85
# 2514567  2.220691       5.0     08930        54        0.0         9.80
#
#          rating  ocio
# 47885      21.0   NaN
# 47886      21.0   NaN
# 47887      21.0   NaN
# 47888      21.0   NaN
# 47889      21.0   NaN
# ...         ...   ...
# 2514563    21.0   NaN
# 2514564    21.0   NaN
# 2514565    21.0   NaN
# 2514566    21.0   NaN
# 2514567    21.0   NaN
#
# [6586 rows x 20 columns]

# %%
full_data['ocio'] = full_data['ocio'].fillna(value = full_data['ocio'].median())
full_data[full_data['ocio'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station_id, year, month, day, hour, ctx-4, ctx-3, ctx-2, ctx-1, percentage_docks_available, date, lat, lon, altitude, post_code, capacity, mm_precip, temperature, rating, ocio]
# Index: []

# %%
len(full_data)
# Out:
# 3274434

# %%
bicis = pd.read_csv('data/locations_data/equipament.csv', encoding = 'utf-16')
carril_bicis = bicis[bicis["name"].str.contains("Carril - Bici")].groupby(['addresses_zip_code']).size().reset_index()
carril_bicis['addresses_zip_code']='0'+carril_bicis['addresses_zip_code'].astype(int).astype(str)
carril_bicis.columns = ['post_code', 'carriles']
carril_bicis.head()
full_data = pd.merge(full_data, carril_bicis, left_on = 'post_code', right_on = 'post_code', how = 'left')
full_data.head()
# Out:
#    station_id    year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0         1.0  2020.0    1.0  1.0   2.0  0.522727  0.503788  0.469697
# 1         1.0  2020.0    1.0  1.0   7.0  0.289773  0.373106  0.304924
# 2         1.0  2020.0    1.0  1.0  12.0  0.253788  0.268939  0.350379
# 3         1.0  2020.0    1.0  1.0  17.0  0.390152  0.346591  0.255814
# 4         1.0  2020.0    1.0  1.0  22.0  0.083333  0.218992  0.437984
#
#       ctx-1  percentage_docks_available  ...        lat       lon  altitude  \
# 0  0.403409                    0.354167  ...  41.397978  2.180107      16.0
# 1  0.238636                    0.240530  ...  41.397978  2.180107      16.0
# 2  0.344697                    0.393939  ...  41.397978  2.180107      16.0
# 3  0.220930                    0.186047  ...  41.397978  2.180107      16.0
# 4  0.515504                    0.470930  ...  41.397978  2.180107      16.0
#
#    post_code capacity  mm_precip  temperature  rating  ocio  carriles
# 0      08013       45        0.0         5.75     6.0  88.0       6.0
# 1      08013       45        0.0         4.25     6.0  88.0       6.0
# 2      08013       45        0.0        12.45     6.0  88.0       6.0
# 3      08013       45        0.0         9.35     6.0  88.0       6.0
# 4      08013       45        0.0         6.80     6.0  88.0       6.0
#
# [5 rows x 21 columns]

# %%
full_data[full_data['carriles'].isna()]
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 13596          10.0  2020.0   10.0   8.0  13.0  0.550000  0.560000  1.000000
# 13597          10.0  2020.0   10.0   8.0  18.0  1.000000  0.650503  0.579268
# 13598          10.0  2020.0   10.0   8.0  23.0  0.560976  0.560976  0.560976
# 13599          10.0  2020.0   10.0   9.0   4.0  0.553571  0.571429  0.571429
# 13600          10.0  2020.0   10.0   9.0   9.0  0.571429  0.559524  0.547619
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 3261460       511.0  2023.0   12.0  31.0   0.0  0.717593  0.555556  0.592593
# 3261461       511.0  2023.0   12.0  31.0   5.0  0.796296  0.879630  0.777778
# 3261462       511.0  2023.0   12.0  31.0  10.0  0.666667  0.680556  0.652778
# 3261463       511.0  2023.0   12.0  31.0  15.0  0.666667  0.712963  0.699074
# 3261464       511.0  2023.0   12.0  31.0  20.0  0.662037  0.673002  0.908626
#
#             ctx-1  percentage_docks_available  ...        lat       lon  \
# 13596    1.000000                    1.000000  ...  41.346775  2.143623
# 13597    0.560976                    0.560976  ...  41.346775  2.143623
# 13598    0.584525                    0.557124  ...  41.346775  2.143623
# 13599    0.571429                    0.571429  ...  41.346775  2.143623
# 13600    0.547619                    0.547619  ...  41.346775  2.143623
# ...           ...                         ...  ...        ...       ...
# 3261460  0.810185                    0.694444  ...  41.400686  2.154332
# 3261461  0.777778                    0.731481  ...  41.400686  2.154332
# 3261462  0.546296                    0.551282  ...  41.400686  2.154332
# 3261463  0.587963                    0.884259  ...  41.400686  2.154332
# 3261464  0.857212                    0.925439  ...  41.400686  2.154332
#
#          altitude  post_code capacity  mm_precip  temperature  rating  ocio  \
# 13596         4.0      08040       43        0.0        22.80    21.0   3.0
# 13597         4.0      08040       43        0.0        18.95    21.0   3.0
# 13598         4.0      08040       43        0.0        17.30    21.0   3.0
# 13599         4.0      08040       43        0.0        16.40    21.0   3.0
# 13600         4.0      08040       43        0.0        23.75    21.0   3.0
# ...           ...        ...      ...        ...          ...     ...   ...
# 3261460      61.0      08012       20        0.0        10.25    68.0  82.0
# 3261461      61.0      08012       20        0.0         9.50    68.0  82.0
# 3261462      61.0      08012       20        0.0        13.95    68.0  82.0
# 3261463      61.0      08012       20        0.0        15.65    68.0  82.0
# 3261464      61.0      08012       20        0.0        10.85    68.0  82.0
#
#          carriles
# 13596         NaN
# 13597         NaN
# 13598         NaN
# 13599         NaN
# 13600         NaN
# ...           ...
# 3261460       NaN
# 3261461       NaN
# 3261462       NaN
# 3261463       NaN
# 3261464       NaN
#
# [628577 rows x 21 columns]

# %%
zip_carriles = np.unique(carril_bicis['post_code'])
not_carriles = [code for code in data_zip if code not in zip_carriles]
not_carriles
# Out:
# ['08004',
#  '08007',
#  '08012',
#  '08021',
#  '08022',
#  '08023',
#  '08024',
#  '08031',
#  '08035',
#  '08036',
#  '08038',
#  '08039',
#  '08040',
#  '08930']

# %%
full_data['carriles'] = full_data['carriles'].fillna(value = full_data['carriles'].median())
full_data[full_data['carriles'].isnull()]
# Out:
# Empty DataFrame
# Columns: [station_id, year, month, day, hour, ctx-4, ctx-3, ctx-2, ctx-1, percentage_docks_available, date, lat, lon, altitude, post_code, capacity, mm_precip, temperature, rating, ocio, carriles]
# Index: []
#
# [0 rows x 21 columns]

# %%
len(full_data)
# Out:
# 3274434

# %%
full_data
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0               1.0  2020.0    1.0   1.0   2.0  0.522727  0.503788  0.469697
# 1               1.0  2020.0    1.0   1.0   7.0  0.289773  0.373106  0.304924
# 2               1.0  2020.0    1.0   1.0  12.0  0.253788  0.268939  0.350379
# 3               1.0  2020.0    1.0   1.0  17.0  0.390152  0.346591  0.255814
# 4               1.0  2020.0    1.0   1.0  22.0  0.083333  0.218992  0.437984
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 3274429       519.0  2023.0   12.0  31.0   1.0  0.913043  0.847826  0.713768
# 3274430       519.0  2023.0   12.0  31.0   6.0  0.648551  0.619565  0.608696
# 3274431       519.0  2023.0   12.0  31.0  11.0  0.826087  0.836957  0.898551
# 3274432       519.0  2023.0   12.0  31.0  16.0  1.000000  1.000000  0.931159
# 3274433       519.0  2023.0   12.0  31.0  21.0  0.887681  0.905797  0.800725
#
#             ctx-1  percentage_docks_available  ...        lat       lon  \
# 0        0.403409                    0.354167  ...  41.397978  2.180107
# 1        0.238636                    0.240530  ...  41.397978  2.180107
# 2        0.344697                    0.393939  ...  41.397978  2.180107
# 3        0.220930                    0.186047  ...  41.397978  2.180107
# 4        0.515504                    0.470930  ...  41.397978  2.180107
# ...           ...                         ...  ...        ...       ...
# 3274429  0.731884                    0.659420  ...  41.424655  2.166289
# 3274430  0.608696                    0.735507  ...  41.424655  2.166289
# 3274431  0.939799                    1.000000  ...  41.424655  2.166289
# 3274432  0.923913                    0.869565  ...  41.424655  2.166289
# 3274433  0.746377                    0.713768  ...  41.424655  2.166289
#
#          altitude  post_code capacity  mm_precip  temperature  rating  ocio  \
# 0            16.0      08013       45        0.0         5.75     6.0  88.0
# 1            16.0      08013       45        0.0         4.25     6.0  88.0
# 2            16.0      08013       45        0.0        12.45     6.0  88.0
# 3            16.0      08013       45        0.0         9.35     6.0  88.0
# 4            16.0      08013       45        0.0         6.80     6.0  88.0
# ...           ...        ...      ...        ...          ...     ...   ...
# 3274429     110.0      08032       24        0.0        11.10    10.0  52.0
# 3274430     110.0      08032       24        0.0         8.95    10.0  52.0
# 3274431     110.0      08032       24        0.0        17.35    10.0  52.0
# 3274432     110.0      08032       24        0.0        13.85    10.0  52.0
# 3274433     110.0      08032       24        0.0         9.80    10.0  52.0
#
#          carriles
# 0             6.0
# 1             6.0
# 2             6.0
# 3             6.0
# 4             6.0
# ...           ...
# 3274429       1.0
# 3274430       1.0
# 3274431       1.0
# 3274432       1.0
# 3274433       1.0
#
# [3274434 rows x 21 columns]

# %%
#data.to_csv('../full_dataframe.csv')
#for year in years:
#    full_data[full_data['year']==year].to_csv('data/full dataframe/dataframe_{}.csv'.format(year))

# %%
full_data.size
# Out:
# 68763114

# %%
# Corregim el float que hi havia a year
full_data['year'] = full_data['year'].astype(int)
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available  ...        lat       lon  altitude  post_code  \
# 0                    0.354167  ...  41.397978  2.180107      16.0      08013
# 1                    0.240530  ...  41.397978  2.180107      16.0      08013
# 2                    0.393939  ...  41.397978  2.180107      16.0      08013
# 3                    0.186047  ...  41.397978  2.180107      16.0      08013
# 4                    0.470930  ...  41.397978  2.180107      16.0      08013
#
#   capacity  mm_precip  temperature  rating  ocio  carriles
# 0       45        0.0         5.75     6.0  88.0       6.0
# 1       45        0.0         4.25     6.0  88.0       6.0
# 2       45        0.0        12.45     6.0  88.0       6.0
# 3       45        0.0         9.35     6.0  88.0       6.0
# 4       45        0.0         6.80     6.0  88.0       6.0
#
# [5 rows x 21 columns]

# %%
# Convertim la date y/m/d/h a timestamp
full_data['timestamp'] = pd.to_datetime(full_data['date'], format='%Y/%m/%d/%H')

# Inici
start_date = pd.Timestamp('2020-01-01 00:00:00')
full_data['time'] = (full_data['timestamp'] - start_date).dt.total_seconds() // 3600
full_data['time'] = full_data['time'].astype(int)

# Ara fem drop de date i timestamp
full_data.drop(columns=['timestamp', 'date'], inplace=True)
full_data['time'].head()
# Out:
# 0     2
# 1     7
# 2    12
# 3    17
# 4    22
# Name: time, dtype: int64

# %%
festius = pd.read_csv('data/festius/Festius_generals_de_Catalunya.csv')
festius
# Out:
#      Any        Data             Nom del festiu
# 0   2020  01/01/2020                  Cap d'Any
# 1   2020  06/01/2020                       Reis
# 2   2020  10/04/2020             Divendres Sant
# 3   2020  13/04/2020  Dilluns de Pasqua Florida
# 4   2020  01/05/2020          Festa del Treball
# ..   ...         ...                        ...
# 75  2025  01/11/2025                 Tots Sants
# 76  2025  06/12/2025      Dia de la Constitució
# 77  2025  08/12/2025              La Immaculada
# 78  2025  25/12/2025                      Nadal
# 79  2025  26/12/2025                Sant Esteve
#
# [80 rows x 3 columns]

# %%
festius['Data'] = pd.to_datetime(festius['Data'], format='%d/%m/%Y')

# Extraiem dia, mes i any per poder comparar amb full data
festius['year'] = festius['Data'].dt.year
festius['month'] = festius['Data'].dt.month
festius['day'] = festius['Data'].dt.day

# %%
full_data = full_data.merge(festius[['year', 'month', 'day']], on=['year', 'month', 'day'], how='left', indicator=True)
full_data['festius'] = (full_data['_merge'] == 'both').astype(int)
full_data.drop(columns=['_merge'], inplace=True)
full_data.head()
# Out:
#    station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         1.0  2020    1.0  1.0   2.0  0.522727  0.503788  0.469697  0.403409
# 1         1.0  2020    1.0  1.0   7.0  0.289773  0.373106  0.304924  0.238636
# 2         1.0  2020    1.0  1.0  12.0  0.253788  0.268939  0.350379  0.344697
# 3         1.0  2020    1.0  1.0  17.0  0.390152  0.346591  0.255814  0.220930
# 4         1.0  2020    1.0  1.0  22.0  0.083333  0.218992  0.437984  0.515504
#
#    percentage_docks_available  ...  altitude  post_code  capacity mm_precip  \
# 0                    0.354167  ...      16.0      08013        45       0.0
# 1                    0.240530  ...      16.0      08013        45       0.0
# 2                    0.393939  ...      16.0      08013        45       0.0
# 3                    0.186047  ...      16.0      08013        45       0.0
# 4                    0.470930  ...      16.0      08013        45       0.0
#
#    temperature  rating  ocio  carriles  time  festius
# 0         5.75     6.0  88.0       6.0     2        1
# 1         4.25     6.0  88.0       6.0     7        1
# 2        12.45     6.0  88.0       6.0    12        1
# 3         9.35     6.0  88.0       6.0    17        1
# 4         6.80     6.0  88.0       6.0    22        1
#
# [5 rows x 22 columns]

# %%
years = full_data['year'].unique()

# Guardem full_data filtrat per anys ja que són fitxers grans
for year in years:
    yearly_data = full_data[full_data['year'] == year]
    yearly_data.to_csv(f'../full_data_{year}.csv', index=False)
    print(f'Saved full_data_{year}.csv')
# Out:
# Saved full_data_2020.csv
# Saved full_data_2021.csv
# Saved full_data_2022.csv
# Saved full_data_2023.csv
