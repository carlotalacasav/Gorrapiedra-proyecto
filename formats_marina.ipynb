# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
months = ['Gener', 'Febrer', 'Marc', 'Abril', 'Maig', 'Juny'] #'Juliol', 'Agost', 'Setembre', 'Octubre', 'Novembre', 'Desembre']
indeces = ['01', '02', '03', '04', '05', '06'] # '07', '08', '09', '10', '11', '12']
years = ['2021'] #['2020', '2021', '2022', '2023']

## OJO ##
# EN 2021 Y 2022 EL DOCUMENTO SE LLAMA MARÇ EN VEZ DE MARC, HAY QUE CAMBIARLO A MARC PARA QUE FUNCIONE

data = pd.DataFrame()
for year in years:
    for index, month in zip(indeces, months):
        month_year = pd.read_csv('../raw_data/{}_{}_{}_BicingNou_ESTACIONS.csv'.format(year, index, month))
        data = pd.concat([data, month_year])

# %%
data['last_updated'] = pd.to_datetime(data['last_updated'], unit='s')
data['last_reported'] = pd.to_datetime(data['last_reported'], unit='s')

# %%
data[data['station_id']==4].head(30)

# last reported entenc que és quan hi ha canvis de bicicletes que entren o surten
# last updated és sempre cada 5 min, quan s'envia la info.
# Out:
#        station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 3               4                   15                                    14
# 508             4                   15                                    14
# 1013            4                   15                                    14
# 1518            4                   15                                    14
# 2023            4                   15                                    14
# 2528            4                   15                                    14
# 3033            4                   15                                    14
# 3538            4                   15                                    14
# 4043            4                   15                                    14
# 4548            4                   15                                    14
# 5053            4                   15                                    15
# ...

# %%
data.columns
# Out:
# Index(['station_id', 'num_bikes_available',
#        'num_bikes_available_types.mechanical',
#        'num_bikes_available_types.ebike', 'num_docks_available',
#        'last_reported', 'is_charging_station', 'status', 'is_installed',
#        'is_renting', 'is_returning', 'last_updated', 'ttl'],
#       dtype='object')

# %%
data['last_updated'] = pd.to_datetime(data['last_updated'], unit='s')
data['last_reported'] = pd.to_datetime(data['last_reported'], unit='s')

# %%
data.head()
# Out:
#    station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 0           1                   43                                    43
# 1           2                   17                                    15
# 2           3                    3                                     3
# 3           4                   15                                    14
# 4           5                    8                                     8
#
#    num_bikes_available_types.ebike  num_docks_available       last_reported  \
# 0                                0                    3 2020-12-31 22:56:46
# 1                                2                   10 2020-12-31 22:57:51
# 2                                0                   22 2020-12-31 22:56:48
# 3                                1                    6 2020-12-31 22:57:38
# 4                                0                   31 2020-12-31 22:57:21
#
# ...

# %%
data['year'] = data['last_updated'].dt.year
data['month'] = data['last_updated'].dt.month
data['day'] = data['last_updated'].dt.day
data['hour'] = data['last_updated'].dt.hour

data.drop(columns=['last_updated'], inplace=True)

data.head()
# Out:
#    station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 0           1                   43                                    43
# 1           2                   17                                    15
# 2           3                    3                                     3
# 3           4                   15                                    14
# 4           5                    8                                     8
#
#    num_bikes_available_types.ebike  num_docks_available       last_reported  \
# 0                                0                    3 2020-12-31 22:56:46
# 1                                2                   10 2020-12-31 22:57:51
# 2                                0                   22 2020-12-31 22:56:48
# 3                                1                    6 2020-12-31 22:57:38
# 4                                0                   31 2020-12-31 22:57:21
#
# ...

# %%
data.columns
# Out:
# Index(['station_id', 'num_bikes_available',
#        'num_bikes_available_types.mechanical',
#        'num_bikes_available_types.ebike', 'num_docks_available',
#        'last_reported', 'is_charging_station', 'status', 'is_installed',
#        'is_renting', 'is_returning', 'ttl', 'percentage_available', 'year',
#        'month', 'day', 'hour'],
#       dtype='object')

# %%
data['percentage_available'] = data['num_bikes_available'] / (data['num_bikes_available'] + data['num_docks_available'])
output_data = data[['station_id', 'year','month', 'day', 'hour', 'percentage_available']].copy()
output_data.reset_index(drop=False, inplace=True)
output_data.rename(columns={'index': 'index'}, inplace=True)
# Out:
#     index  station_id  year  month  day  hour  percentage_available
# 0       0           1  2020     12   31    23              0.934783
# 1       1           2  2020     12   31    23              0.629630
# 2       2           3  2020     12   31    23              0.120000
# 3       3           4  2020     12   31    23              0.714286
# 4       4           5  2020     12   31    23              0.205128
# 5       5           6  2020     12   31    23              0.351351
# 6       6           7  2020     12   31    23              0.461538
# 7       7           8  2020     12   31    23              0.592593
# 8       8           9  2020     12   31    23              0.440000
# 9       9          10  2020     12   31    23              0.452381
# 10     10          11  2020     12   31    23              0.428571
# 11     11          12  2020     12   31    23              0.000000
# 12     12          13  2020     12   31    23              0.740741
# ...

# %%
print('nombre estacions: ', len(np.unique(output_data['station_id'])))
# Out:
# nombre estacions:  509

# %%
output_data[output_data['station_id']==4].head(13)
# Out:
#       index  station_id  year  month  day  hour  percentage_available
# 3         3           4  2020     12   31    23              0.714286
# 508     508           4  2020     12   31    23              0.714286
# 1013   1013           4  2020     12   31    23              0.714286
# 1518   1518           4  2020     12   31    23              0.714286
# 2023   2023           4  2020     12   31    23              0.714286
# 2528   2528           4  2020     12   31    23              0.714286
# 3033   3033           4  2020     12   31    23              0.714286
# 3538   3538           4  2020     12   31    23              0.714286
# 4043   4043           4  2020     12   31    23              0.714286
# 4548   4548           4  2020     12   31    23              0.714286
# 5053   5053           4  2020     12   31    23              0.714286
# 5558   5558           4  2020     12   31    23              0.619048
# ...

# %%
grouped = output_data.groupby(['station_id', 'year', 'month', 'day'])

output_data['ctx-1h'] = grouped['percentage_available'].shift(-12)
output_data['ctx-2h'] = grouped['percentage_available'].shift(-24)
output_data['ctx-3h'] = grouped['percentage_available'].shift(-36)
output_data['ctx-4h'] = grouped['percentage_available'].shift(-48)

# %%
output_data.head(5000)
# Out:
#       index  station_id  year  month  day  hour  percentage_available  ctx-1h  \
# 0         0           1  2020     12   31    23              0.934783     NaN
# 1         1           2  2020     12   31    23              0.629630     NaN
# 2         2           3  2020     12   31    23              0.120000     NaN
# 3         3           4  2020     12   31    23              0.714286     NaN
# 4         4           5  2020     12   31    23              0.205128     NaN
# ...     ...         ...   ...    ...  ...   ...                   ...     ...
# 4995   4995         464  2020     12   31    23              0.478261     NaN
# 4996   4996         465  2020     12   31    23              0.333333     NaN
# 4997   4997         466  2020     12   31    23              0.103448     NaN
# 4998   4998         468  2020     12   31    23              0.222222     NaN
# 4999   4999         469  2020     12   31    23              0.277778     NaN
#
#       ctx-2h  ctx-3h  ctx-4h
# ...

# %%
# Group the data by station_id, month, day, and hour
grouped = data.groupby(['station_id', 'month', 'day', 'hour'])

# Calculate the percentage of available bikes for each station at different time intervals
data['percentage_available'] = data['num_bikes_available'] / (data['num_bikes_available'] + data['num_docks_available'])

# Function to calculate the context for each hour
def calculate_context(group):
    context = {}
    for i in range(1, 5):
        shifted = group['percentage_available'].shift(i)
        context[f'ctx-{i}'] = shifted.fillna(method='bfill')
    return pd.Series(context)

# Apply the function to each group and concatenate the results
contexts = grouped.apply(calculate_context)

# Combine the original DataFrame with the calculated contexts
result = pd.concat([data[['station_id', 'month', 'day', 'hour']], contexts], axis=1)

# Reset index and write to CSV
result.reset_index(drop=True, inplace=True)
result.to_csv('output.csv', index_label='index')
# Out:
# /tmp/ipykernel_67752/3465403086.py:12: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   context[f'ctx-{i}'] = shifted.fillna(method='bfill')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_67752/3465403086.py in ?()
#      12         context[f'ctx-{i}'] = shifted.fillna(method='bfill')
#      13     return pd.Series(context)
#      14
#      15 # Apply the function to each group and concatenate the results
# ---> 16 contexts = grouped.apply(calculate_context)
#      17
#      18 # Combine the original DataFrame with the calculated contexts
#      19 result = pd.concat([data[['station_id', 'month', 'day', 'hour']], contexts], axis=1)
#
# ~/postgrau/Capstone/env/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in ?(self, func, include_groups, *args, **kwargs)
# ...
