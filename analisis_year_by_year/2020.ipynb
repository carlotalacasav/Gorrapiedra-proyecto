# %% [markdown]
# # Analisis del año 2020
# Alejandro Jaramillo
#
# 19/04/2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
months = ['Gener', 'Febrer', 'Marc', 'Abril', 'Maig', 'Juny', 'Juliol', 'Agost', 'Setembre', 'Octubre', 'Novembre', 'Desembre']
indeces = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#years = ['2020', '2021', '2022', '2023']

# %%
## OJO ##
# EN 2021 Y 2022 EL DOCUMENTO SE LLAMA MARÇ EN VEZ DE MARC, HAY QUE CAMBIARLO A MARC PARA QUE FUNCIONE

years = [2020]

data = pd.DataFrame()
for year in years:
    for index, month in zip(indeces, months):
        month_year = pd.read_csv('../../raw_data/{}_{}_{}_BicingNou_ESTACIONS.csv'.format(year, index, month))
        data = pd.concat([data, month_year])

# %%
data
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 4419109         515                   11
# 4419110         516                   18
# 4419111         517                   18
# 4419112         518                    6
# 4419113         519                    2
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 4419109                                    10
# 4419110                                    18
# 4419111                                    17
# 4419112                                     0
# 4419113                                     0
#
#          num_bikes_available_types.ebike  num_docks_available  is_installed  \
# 0                                      0                   23             1
# 1                                      1                   16             1
# 2                                      0                    9             1
# 3                                      0                   13             1
# 4                                      3                   24             1
# ...                                  ...                  ...           ...
# 4419109                                1                   11             1
# 4419110                                0                    3             1
# 4419111                                1                    5             1
# 4419112                                6                   20             1
# 4419113                                2                   22             1
#
#          is_renting  is_returning  last_reported  is_charging_station  \
# 0                 1             1   1.577833e+09                 True
# 1                 1             1   1.577833e+09                 True
# 2                 1             1   1.577833e+09                 True
# 3                 1             1   1.577833e+09                 True
# 4                 1             1   1.577833e+09                 True
# ...             ...           ...            ...                  ...
# 4419109           1             1   1.609455e+09                 True
# 4419110           1             1   1.609455e+09                 True
# 4419111           1             1   1.609455e+09                 True
# 4419112           1             1   1.609455e+09                 True
# 4419113           1             1   1.609455e+09                 True
#
#              status  last_updated  ttl
# 0        IN_SERVICE    1577833223   28
# 1        IN_SERVICE    1577833223   28
# 2        IN_SERVICE    1577833223   28
# 3        IN_SERVICE    1577833223   28
# 4        IN_SERVICE    1577833223   28
# ...             ...           ...  ...
# 4419109  IN_SERVICE    1609455330   26
# 4419110  IN_SERVICE    1609455330   26
# 4419111  IN_SERVICE    1609455330   26
# 4419112  IN_SERVICE    1609455330   26
# 4419113  IN_SERVICE    1609455330   26
#
# [46038633 rows x 13 columns]

# %%
data.hist('station_id', bins = 100)
# uniforme, mismas instancias de todos los valores
# Out:
# array([[<Axes: title={'center': 'station_id'}>]], dtype=object)

# %%
data.hist('num_bikes_available', bins = 30)
# no hay outliers
# Out:
# array([[<Axes: title={'center': 'num_bikes_available'}>]], dtype=object)

# %%
data.hist('num_bikes_available_types.mechanical')
# no hay outliers
# Out:
# array([[<Axes: title={'center': 'num_bikes_available_types.mechanical'}>]],
#       dtype=object)

# %%
data.hist('num_bikes_available_types.ebike')
# no hay outliers
# Out:
# array([[<Axes: title={'center': 'num_bikes_available_types.ebike'}>]],
#       dtype=object)

# %%
data.hist('last_reported', bins = 50)
# Out:
# array([[<Axes: title={'center': 'last_reported'}>]], dtype=object)

# %%
print(data['is_charging_station'].value_counts())
data['is_charging_station'].value_counts().plot.bar()
# Out:
# is_charging_station
# True     46038105
# False         528
# Name: count, dtype: int64
# <Axes: xlabel='is_charging_station'>

# %%
print(data['status'].value_counts())
data['status'].value_counts().plot.bar()
# Out:
# status
# IN_SERVICE        42580426
# MAINTENANCE        3223668
# PLANNED             161489
# NOT_IN_SERVICE       73042
# END_OF_LIFE              8
# Name: count, dtype: int64
# <Axes: xlabel='status'>

# %%
print(data['is_installed'].value_counts())
data['is_installed'].value_counts().plot.bar()
# Out:
# is_installed
# 1    45877144
# 0      161489
# Name: count, dtype: int64
# <Axes: xlabel='is_installed'>

# %%
print(data['is_renting'].value_counts())
data['is_renting'].value_counts().plot.bar()
# Out:
# is_renting
# 1    42577392
# 0     3461241
# Name: count, dtype: int64
# <Axes: xlabel='is_renting'>

# %%
print(data['is_returning'].value_counts())
data['is_returning'].value_counts().plot.bar()
# Out:
# is_returning
# 1    42580426
# 0     3458207
# Name: count, dtype: int64
# <Axes: xlabel='is_returning'>

# %%
#print(data['traffic'].value_counts())
# no hay nada
# no existe esta feature en 2020

# %%
#data['traffic']

# %%
data.hist('last_updated', bins = 50)
# Out:
# array([[<Axes: title={'center': 'last_updated'}>]], dtype=object)

# %%
data.hist('ttl', bins = 50)
# Out:
# array([[<Axes: title={'center': 'ttl'}>]], dtype=object)

# %%
data['ttl'].value_counts()
# Out:
# ttl
# 30    5268526
# 29    1849666
# 28    1699656
# 22    1602564
# 23    1573668
# 24    1523562
# 27    1513871
# 21    1489139
# 20    1486360
# 19    1480833
# 26    1468993
# 25    1453204
# 18    1400816
# 17    1364667
# 5     1357929
# 16    1347968
# 1     1345302
# 15    1336861
# 11    1315851
# 6     1310950
# 2     1301874
# 10    1284700
# 8     1284275
# 4     1278199
# 9     1276134
# 7     1275654
# 14    1271245
# 12    1264570
# 3     1261066
# 13    1251115
# 0       99415
# Name: count, dtype: int64

# %%
for column in data.columns:
    print('NaNs in {}: {}'.format(column, data[column].isna().sum()))
# Out:
# NaNs in station_id: 0
# NaNs in num_bikes_available: 0
# NaNs in num_bikes_available_types.mechanical: 0
# NaNs in num_bikes_available_types.ebike: 0
# NaNs in num_docks_available: 0
# NaNs in is_installed: 0
# NaNs in is_renting: 0
# NaNs in is_returning: 0
# NaNs in last_reported: 0
# NaNs in is_charging_station: 0
# NaNs in status: 0
# NaNs in last_updated: 0
# NaNs in ttl: 0

# %%
data['station_id'].isna().value_counts()
# Out:
# station_id
# False    52849042
# Name: count, dtype: int64

# %%
stations_2020 = data['station_id'].unique()
not_in_2020 = [i for i in range(1,max(stations_2020)) if i not in stations_2020]
not_in_2020
# Out:
# [16, 38, 52, 91, 169, 172, 181, 407, 431, 453, 467, 528]

# %%
max(stations_2020)
# Out:
# 530
