# %% [markdown]
# # Analisis del año 2023
# Alejandro Jaramillo
#
# 19/04/2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
months = ['Gener', 'Febrer', 'Marc', 'Abril', 'Maig', 'Juny', 'Juliol', 'Agost', 'Setembre', 'Octubre', 'Novembre', 'Desembre']
indeces = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#years = ['2020', '2021', '2022', '2023']

# %%
## OJO ##
# EN 2021 Y 2022 EL DOCUMENTO SE LLAMA MARÇ EN VEZ DE MARC, HAY QUE CAMBIARLO A MARC PARA QUE FUNCIONE

years = [2023]

data = pd.DataFrame()
for year in years:
    for index, month in zip(indeces, months):
        month_year = pd.read_csv('../../raw_data/{}_{}_{}_BicingNou_ESTACIONS.csv'.format(year, index, month))
        data = pd.concat([data, month_year])
# Out:
# /var/folders/gt/v7xq73cx0nj74cmjgsw8ql_00000gn/T/ipykernel_45708/3541788293.py:9: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   month_year = pd.read_csv('../../raw_data/{}_{}_{}_BicingNou_ESTACIONS.csv'.format(year, index, month))
# /var/folders/gt/v7xq73cx0nj74cmjgsw8ql_00000gn/T/ipykernel_45708/3541788293.py:9: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   month_year = pd.read_csv('../../raw_data/{}_{}_{}_BicingNou_ESTACIONS.csv'.format(year, index, month))

# %%
data
# Out:
#          station_id  num_bikes_available  \
# 0               1.0                 38.0
# 1               2.0                  6.0
# 2               3.0                 20.0
# 3               4.0                 19.0
# 4               5.0                  4.0
# ...             ...                  ...
# 4525541       515.0                  5.0
# 4525542       516.0                 10.0
# 4525543       517.0                  8.0
# 4525544       518.0                  3.0
# 4525545       519.0                  6.0
#
#          num_bikes_available_types.mechanical  \
# 0                                        35.0
# 1                                         5.0
# 2                                        20.0
# 3                                        19.0
# 4                                         3.0
# ...                                       ...
# 4525541                                   5.0
# 4525542                                   2.0
# 4525543                                   1.0
# 4525544                                   1.0
# 4525545                                   0.0
#
#          num_bikes_available_types.ebike  num_docks_available  last_reported  \
# 0                                    3.0                  8.0   1.672528e+09
# 1                                    1.0                 23.0   1.672527e+09
# 2                                    0.0                  7.0   1.672527e+09
# 3                                    0.0                  2.0   1.672528e+09
# 4                                    1.0                 35.0   1.672527e+09
# ...                                  ...                  ...            ...
# 4525541                              0.0                 19.0   1.704064e+09
# 4525542                              8.0                 10.0   1.704064e+09
# 4525543                              7.0                 11.0   1.704064e+09
# 4525544                              2.0                 24.0   1.704064e+09
# 4525545                              6.0                 17.0   1.704064e+09
#
#         is_charging_station      status  is_installed  is_renting  \
# 0                      True  IN_SERVICE           1.0         1.0
# 1                      True  IN_SERVICE           1.0         1.0
# 2                      True  IN_SERVICE           1.0         1.0
# 3                      True  IN_SERVICE           1.0         1.0
# 4                      True  IN_SERVICE           1.0         1.0
# ...                     ...         ...           ...         ...
# 4525541                True  IN_SERVICE           1.0         1.0
# 4525542                True  IN_SERVICE           1.0         1.0
# 4525543                True  IN_SERVICE           1.0         1.0
# 4525544                True  IN_SERVICE           1.0         1.0
# 4525545                True  IN_SERVICE           1.0         1.0
#
#          is_returning  traffic  last_updated   ttl  V1
# 0                 1.0      NaN  1.672528e+09  19.0 NaN
# 1                 1.0      NaN  1.672528e+09  19.0 NaN
# 2                 1.0      NaN  1.672528e+09  19.0 NaN
# 3                 1.0      NaN  1.672528e+09  19.0 NaN
# 4                 1.0      NaN  1.672528e+09  19.0 NaN
# ...               ...      ...           ...   ...  ..
# 4525541           1.0      NaN  1.704065e+09   1.0 NaN
# 4525542           1.0      NaN  1.704065e+09   1.0 NaN
# 4525543           1.0      NaN  1.704065e+09   1.0 NaN
# 4525544           1.0      NaN  1.704065e+09   1.0 NaN
# 4525545           1.0      NaN  1.704065e+09   1.0 NaN
#
# [49193647 rows x 15 columns]

# %%
data.hist('station_id', bins = 100)
# uniforme, mismas instancias de todos los valores
# Out:
# array([[<Axes: title={'center': 'station_id'}>]], dtype=object)

# %%
data.hist('num_bikes_available', bins = 30)
# no hay outliers
# Out:
# array([[<Axes: title={'center': 'num_bikes_available'}>]], dtype=object)

# %%
data.hist('num_bikes_available_types.mechanical')
# no hay outliers
# Out:
# array([[<Axes: title={'center': 'num_bikes_available_types.mechanical'}>]],
#       dtype=object)

# %%
data.hist('num_bikes_available_types.ebike')
# no hay outliers
# Out:
# array([[<Axes: title={'center': 'num_bikes_available_types.ebike'}>]],
#       dtype=object)

# %%
data.hist('last_reported', bins = 50)
# Out:
# array([[<Axes: title={'center': 'last_reported'}>]], dtype=object)

# %%
print(data['is_charging_station'].value_counts())
data['is_charging_station'].value_counts().plot.bar()
# Out:
# is_charging_station
# True    49189882
# Name: count, dtype: int64
# <Axes: xlabel='is_charging_station'>

# %%
print(data['status'].value_counts())
data['status'].value_counts().plot.bar()
# Out:
# status
# IN_SERVICE        49073608
# NOT_IN_SERVICE      107109
# MAINTENANCE           8997
# PLANNED                168
# Name: count, dtype: int64
# <Axes: xlabel='status'>

# %%
print(data['is_installed'].value_counts())
data['is_installed'].value_counts().plot.bar()
# Out:
# is_installed
# 1.0    49189714
# 0.0         168
# Name: count, dtype: int64
# <Axes: xlabel='is_installed'>

# %%
print(data['is_renting'].value_counts())
data['is_renting'].value_counts().plot.bar()
# Out:
# is_renting
# 1.0    49073492
# 0.0      116390
# Name: count, dtype: int64
# <Axes: xlabel='is_renting'>

# %%
print(data['is_returning'].value_counts())
data['is_returning'].value_counts().plot.bar()
# Out:
# is_returning
# 1.0    49073608
# 0.0      116274
# Name: count, dtype: int64
# <Axes: xlabel='is_returning'>

# %%
print(data['traffic'].value_counts())
# no hay nada
# Out:
# Series([], Name: count, dtype: int64)

# %%
data['traffic']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 4525541   NaN
# 4525542   NaN
# 4525543   NaN
# 4525544   NaN
# 4525545   NaN
# Name: traffic, Length: 49193647, dtype: float64

# %%
data.hist('last_updated', bins = 50)
# Out:
# array([[<Axes: title={'center': 'last_updated'}>]], dtype=object)

# %%
data.hist('ttl', bins = 50)
# Out:
# array([[<Axes: title={'center': 'ttl'}>]], dtype=object)

# %%
data['ttl'].value_counts()
# Out:
# ttl
# 0.0       10936333
# 1.0        2473090
# 19.0       1457524
# 21.0       1429478
# 20.0       1428535
# 2.0        1380806
# 9.0        1363319
# 17.0       1361177
# 18.0       1325340
# 22.0       1315756
# 24.0       1289849
# 13.0       1287193
# 26.0       1281104
# 23.0       1264003
# 3.0        1255205
# 4.0        1231437
# 14.0       1230296
# 16.0       1224068
# 15.0       1217955
# 25.0       1207590
# 5.0        1199817
# 11.0       1198234
# 27.0       1177440
# 12.0       1171778
# 8.0        1169169
# 7.0        1167306
# 6.0        1164035
# 29.0       1163826
# 10.0       1153287
# 28.0       1137566
# 30.0        526856
# 2995.0         510
# Name: count, dtype: int64

# %%
for column in data.columns:
    print('NaNs in {}: {}'.format(column, data[column].isna().sum()))
# Out:
# NaNs in station_id: 3765
# NaNs in num_bikes_available: 3765
# NaNs in num_bikes_available_types.mechanical: 3765
# NaNs in num_bikes_available_types.ebike: 3765
# NaNs in num_docks_available: 3765
# NaNs in last_reported: 3765
# NaNs in is_charging_station: 3765
# NaNs in status: 3765
# NaNs in is_installed: 3765
# NaNs in is_renting: 3765
# NaNs in is_returning: 3765
# NaNs in traffic: 49193647
# NaNs in last_updated: 3765
# NaNs in ttl: 3765
# NaNs in V1: 49193647

# %%
data['station_id'].isna().value_counts()
# Out:
# station_id
# False    49189882
# True         3765
# Name: count, dtype: int64

# %%
stations_2023 = data['station_id'].astype(int).unique()
not_in_2023 = [i for i in range(1,max(stations_2023)) if i not in stations_2023]
not_in_2023
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 stations_2023 = data['station_id'].astype(int).unique()
#       2 not_in_2023 = [i for i in range(1,max(stations_2023)) if i not in stations_2023]
#       3 not_in_2023
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
stations_2023 = data['station_id'].astype(int).unique()
stations_2023
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 stations_2023 = data['station_id'].astype(int).unique()
#       2 stations_2023
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~/miniconda3/envs/PG/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
